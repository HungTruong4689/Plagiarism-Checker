# %%
import cProfile
import pandas as pd
#import sys
from sqlalchemy import create_engine
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import spacy
from sklearn.feature_extraction.text import CountVectorizer
import string
import concurrent.futures
import time
import optparse


## Implement the string data

def remove_punctuations(txt, punct = string.punctuation):
    '''
    This function will remove punctuations from the input text
    '''
    return ''.join([c for c in txt if c not in punct])

def remove_stopwords(txt, sw = list(stopwords.words('english'))):
    '''
    This function will remove the stopwords from the input txt
    '''
    return ' '.join([w for w in txt.split() if w.lower() not in sw])


en_nlp = spacy.load('en_core_web_sm')

def clean_text(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)
    txt = remove_stopwords(txt)
    return txt.lower()

def clean_text_vi(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)

    return txt.lower()
def lemma_text(text_line):
    #test_file_clean = []
    doc_spacy = en_nlp(text_line)
    line = [ a.lemma_ for a in doc_spacy]
    #sentence = " ".join(line)
    #test_file_clean.append(sentence)
    return " ".join(line)



vectorizer1 = CountVectorizer(ngram_range=(2,4),stop_words="english")
vectorizer2 = CountVectorizer(ngram_range=(2,4),stop_words="english",min_df=0.55)

class Checker():
    ## Connect to the MySQL server
    engine = create_engine('mysql://root:kakalot123@localhost:3306/db')
    # book_id =177
    # language = 'en'
    def __init__(self,version,score,test_id):
        self.version = version
        self.score = score
        self.test_id = test_id
        if(self.version =='esv'):
            self.book_id =177
            self.language ='en'
        elif(self.version =='vie2010'):
            self.book_id =397
            self.language ='vi'
        self.train_query = """select verses.id,verses.text from verses   where verses.book_id!={} and books.language='{}' and books.version='{}'""".format(self.book_id,self.language,self.version)
        self.train_model = pd.read_sql_query(self.train_query, self.engine)
        # print(self.test_id)
        # print(self.version)
        # print(self.book_id)
        # print(self.language)
        self.test_query = """select verses.id,verses.textfrom verses  inner join books on verses.book_id = books.id where verses.book_id={} and books.language='{}' and verses.id ={} and books.version='{}'""".format(self.book_id,self.language,self.test_id,self.version)
        self.test_model = pd.read_sql_query(self.test_query,self.engine).drop(['books_id','name','short_name','version','language'],axis=1)
        self.text = self.train_model['text'].tolist()
        self.verses_id = self.train_model['id'].tolist()
        self.s_vector = list(zip(self.verses_id,self.text))
        self.test_file = self.test_model['text'].apply(str)

    def check_plagiarism(self,train_file,test_file,vectorizer):
        documents = [train_file,test_file]
        sparse_matrix = vectorizer.fit_transform(documents)
        score = cosine_similarity(sparse_matrix)[0][1]
        return score
    def show_result(self,train_file,test_file):

        score = self.check_plagiarism(train_file,test_file,vectorizer1)
        if score >float(self.score):
            score = self.check_plagiarism(train_file,test_file,vectorizer2)
        return score



    #def check_plagiarism_soft(self,test_file,s_vector):
    def check_plagiarism_soft(self,test_file,text,verses_id):
        self.test_file = test_file
        self.text = text
        self.verses_id = verses_id
        #self.s_vector = s_vector
        result = {"id":[],"score":[]}

        if(self.version=='esv'):
            self.text = [clean_text(txt) for txt in self.text]
            self.text = [lemma_text(txt) for txt in self.text ]
            self.test_file = clean_text(self.test_file)
            self.test_file = lemma_text(self.test_file)
        elif(self.version =='vie2010'):
            self.test_file = clean_text_vi(self.test_file)
        test_file_list =[]
        for i in range(len(self.text)):
            test_file_list.append(self.test_file)
        result['id'] = verses_id
        with concurrent.futures.ProcessPoolExecutor() as executor:
            score = executor.map(self.show_result,self.text,test_file_list)
        result['score'] = score

#         for a,v_vector in self.s_vector:
#             test_file = clean_text(self.test_file)

#             if(self.version=='esv'):
#                 v_vector = clean_text(v_vector)
#                 test_file = lemma_text(test_file)
#                 v_vector = lemma_text(v_vector)
#             elif(self.version =='vie2010'):
#                 v_vector = clean_text_vi(v_vector)
#             score = self.show_result(v_vector,test_file)
#             result['id'].append(a)
#                 #score.append(executor.submit(self.show_result, train_file=v_vector,test_file=test_file))
#             result['score'].append(score)

        #     result['score'] = score
        dt = pd.DataFrame(result)
        result_file =[dt.loc[dt['score']==max(dt['score'])]['id'].tolist()[0],dt.loc[dt['score']==max(dt['score'])]['score'].tolist()[0]]
        return result_file


    def show_final_result(self):
        #result = self.check_plagiarism_soft(self.test_file,self.s_vector)
        result = self.check_plagiarism_soft(self.test_file,self.text,self.verses_id)
        result_model = pd.read_sql_query(f"select verses.id,verses.book_id,verses.chapter,verses.number,verses.text from verses where verses.id={result[0]}", self.engine)
        result_model['score'] = result[1]
        df = result_model.to_json(orient='table',index=False)
        return df






def main():
    start = time.time()
    parser = optparse.OptionParser()

    # add options
    parser.add_option('-v','--version', dest = 'version',
                      type = 'string',
                      help = 'choose english or vietnamese version')
    parser.add_option('-t','--testid', dest = 'testid',
                      type = 'string',
                      help = 'please enter the test id')
    parser.add_option('-s','--score', dest = 'score',
                      type = 'string',
                      help = 'please enter the algorithm score')


    (options, args) = parser.parse_args()
    if (options.version == None):
            print ("Version is not null")
            exit(0)
    else:
            version = options.version

    if (options.testid == None):
            print ("Test id is not null")
            exit(0)
    else:
            testid = options.testid

    if (options.score == None):
            print ("The score is not null")
            exit(0)
    else:
            score = options.score
    my_checker = Checker(version,score,testid)
    print(my_checker.version)
    print(my_checker.score)
    print(my_checker.test_id)
    print(my_checker.show_final_result())

    end = time.time()
    print("It takes: ",end -start)


if __name__ == "__main__":
    cProfile.run('main()')
# Out:
#          431 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <ipython-input-11-0595df672f15>:164(main)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#        16    0.000    0.000    0.000    0.000 _collections_abc.py:657(get)
#         4    0.000    0.000    0.000    0.000 gettext.py:212(_expand_lang)
#         4    0.000    0.000    0.000    0.000 gettext.py:538(find)
#         4    0.000    0.000    0.000    0.000 gettext.py:579(translation)
#         4    0.000    0.000    0.000    0.000 gettext.py:660(dgettext)
#         4    0.000    0.000    0.000    0.000 gettext.py:735(gettext)
#         4    0.000    0.000    0.000    0.000 iostream.py:197(schedule)
#         3    0.000    0.000    0.000    0.000 iostream.py:310(_is_master_process)
#         3    0.000    0.000    0.000    0.000 iostream.py:323(_schedule_flush)
#         3    0.000    0.000    0.000    0.000 iostream.py:386(write)
#         4    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#         4    0.000    0.000    0.000    0.000 locale.py:384(normalize)
#         2    0.000    0.000    0.000    0.000 ntpath.py:124(splitdrive)
#         2    0.000    0.000    0.000    0.000 ntpath.py:180(split)
#         2    0.000    0.000    0.000    0.000 ntpath.py:214(basename)
#         2    0.000    0.000    0.000    0.000 ntpath.py:34(_get_bothseps)
#         1    0.000    0.000    0.000    0.000 optparse.py:1178(__init__)
#         1    0.000    0.000    0.000    0.000 optparse.py:1230(_create_option_list)
#         1    0.000    0.000    0.000    0.000 optparse.py:1235(_add_help_option)
#         1    0.000    0.000    0.000    0.000 optparse.py:1245(_populate_option_list)
#         1    0.000    0.000    0.000    0.000 optparse.py:1255(_init_parsing_state)
#         1    0.000    0.000    0.000    0.000 optparse.py:1264(set_usage)
#         1    0.000    0.000    0.000    0.000 optparse.py:1300(_get_all_options)
#         1    0.000    0.000    0.000    0.000 optparse.py:1306(get_default_values)
#         1    0.000    0.000    0.000    0.000 optparse.py:1349(_get_args)
#         1    0.000    0.000    0.000    0.000 optparse.py:1355(parse_args)
#         1    0.000    0.000    0.000    0.000 optparse.py:1407(_process_args)
#         1    0.000    0.000    0.000    0.000 optparse.py:142(__init__)
#         1    0.000    0.000    0.000    0.000 optparse.py:145(__str__)
#         1    0.000    0.000    0.000    0.000 optparse.py:1503(_process_short_opts)
#         2    0.000    0.000    0.000    0.000 optparse.py:1544(get_prog_name)
#         1    0.000    0.000    0.000    0.000 optparse.py:1550(expand_prog_name)
#         1    0.000    0.000    0.000    0.000 optparse.py:1556(exit)
#         1    0.000    0.000    0.000    0.000 optparse.py:1561(error)
#         1    0.000    0.000    0.000    0.000 optparse.py:1571(get_usage)
#         1    0.000    0.000    0.000    0.000 optparse.py:1578(print_usage)
#         1    0.000    0.000    0.000    0.000 optparse.py:206(__init__)
#         1    0.000    0.000    0.000    0.000 optparse.py:231(set_parser)
#         1    0.000    0.000    0.000    0.000 optparse.py:372(__init__)
#         1    0.000    0.000    0.000    0.000 optparse.py:380(format_usage)
#         4    0.000    0.000    0.000    0.000 optparse.py:564(__init__)
#         4    0.000    0.000    0.000    0.000 optparse.py:583(_check_opt_strings)
#         4    0.000    0.000    0.000    0.000 optparse.py:587(<listcomp>)
#         4    0.000    0.000    0.000    0.000 optparse.py:592(_set_opt_strings)
#         4    0.000    0.000    0.000    0.000 optparse.py:613(_set_attrs)
#         4    0.000    0.000    0.000    0.000 optparse.py:632(_check_action)
#         4    0.000    0.000    0.000    0.000 optparse.py:638(_check_type)
#         4    0.000    0.000    0.000    0.000 optparse.py:662(_check_choice)
#         4    0.000    0.000    0.000    0.000 optparse.py:675(_check_dest)
#         4    0.000    0.000    0.000    0.000 optparse.py:690(_check_const)
#         4    0.000    0.000    0.000    0.000 optparse.py:696(_check_nargs)
#         4    0.000    0.000    0.000    0.000 optparse.py:705(_check_callback)
#         1    0.000    0.000    0.000    0.000 optparse.py:825(__init__)
#         1    0.000    0.000    0.000    0.000 optparse.py:920(__init__)
#         1    0.000    0.000    0.000    0.000 optparse.py:931(_create_option_mappings)
#         1    0.000    0.000    0.000    0.000 optparse.py:947(set_conflict_handler)
#         1    0.000    0.000    0.000    0.000 optparse.py:952(set_description)
#         4    0.000    0.000    0.000    0.000 optparse.py:968(_check_conflict)
#         4    0.000    0.000    0.000    0.000 optparse.py:995(add_option)
#        17    0.000    0.000    0.000    0.000 os.py:670(__getitem__)
#        17    0.000    0.000    0.000    0.000 os.py:734(check_str)
#        17    0.000    0.000    0.000    0.000 os.py:740(encodekey)
#         4    0.000    0.000    0.000    0.000 socket.py:432(send)
#         4    0.000    0.000    0.000    0.000 threading.py:1017(_wait_for_tstate_lock)
#         4    0.000    0.000    0.000    0.000 threading.py:1071(is_alive)
#         4    0.000    0.000    0.000    0.000 threading.py:513(is_set)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#        35    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        51    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         4    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#         3    0.000    0.000    0.000    0.000 {built-in method nt.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.exit}
#         1    0.000    0.000    0.000    0.000 {built-in method time.time}
#         4    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#        24    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        12    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#        13    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         3    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        17    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
# Usage: ipykernel_launcher.py [options]
#
# ipykernel_launcher.py: error: no such option: -f

# %%
def main():
    start = time.time()
    parser = optparse.OptionParser()

    # add options
    parser.add_option('-v','--version', dest = 'version',
                      type = 'string',
                      help = 'choose english or vietnamese version')
    parser.add_option('-t','--testid', dest = 'testid',
                      type = 'string',
                      help = 'please enter the test id')
    parser.add_option('-s','--score', dest = 'score',
                      type = 'string',
                      help = 'please enter the algorithm score')


#     (options, args) = parser.parse_args()
#     if (options.version == None):
#             print ("Version is not null")
#             exit(0)
#     else:
#             version = options.version

#     if (options.testid == None):
#             print ("Test id is not null")
#             exit(0)
#     else:
#             testid = options.testid

#     if (options.score == None):
#             print ("The score is not null")
#             exit(0)
#     else:
#             score = options.score
    my_checker = Checker('vie2010','0.3','199107')
    print(my_checker.version)
    print(my_checker.score)
    print(my_checker.test_id)
    print(my_checker.show_final_result())

    end = time.time()
    print("It takes: ",end -start)


if __name__ == "__main__":
    import cProfile, pstats
    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('ncalls')
    stats.print_stats()
# Out:
# vie2010
# 0.3
# 199107
# {"schema":{"fields":[{"name":"id","type":"integer"},{"name":"book_id","type":"integer"},{"name":"chapter","type":"integer"},{"name":"number","type":"integer"},{"name":"text","type":"string"},{"name":"score","type":"number"}],"pandas_version":"0.20.0"},"data":[{"id":199539,"book_id":398,"chapter":1,"number":1,"text":"Phao-l\u00f4, b\u1edfi \u00fd \u0111\u1ecbnh c\u1ee7a \u0110\u1ee9c Ch\u00faa Tr\u1eddi, \u0111\u01b0\u1ee3c k\u00eau g\u1ecdi l\u00e0m s\u1ee9 \u0111\u1ed3 c\u1ee7a \u0110\u1ea5ng Christ J\u00easus, c\u00f9ng v\u1edbi S\u1ed1t-then, anh em ch\u00fang ta,","score":1.0}]}
# It takes:  54.878434896469116
#          69998551 function calls (69813469 primitive calls) in 54.878 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
# 6186759/6094944    1.109    0.000    1.896    0.000 {built-in method builtins.isinstance}
# 4965278/4965083    0.407    0.000    0.407    0.000 {built-in method builtins.len}
#   4553912    0.331    0.000    0.331    0.000 {method 'append' of 'list' objects}
#   4400224    0.919    0.000    0.919    0.000 {method 'join' of 'str' objects}
# 2448451/2448446    0.750    0.000    0.750    0.000 {built-in method numpy.asarray}
#   2114408    0.287    0.000    0.332    0.000 {built-in method builtins.getattr}
# 1652692/1652687    1.606    0.000    2.964    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#   1560804    0.199    0.000    0.199    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:80(get_shape)
#   1316276    0.441    0.000    0.634    0.000 {built-in method builtins.hasattr}
#   1224190    0.122    0.000    0.122    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:498(can_cast)
#   1224190    0.601    0.000    1.706    0.000 <__array_function__ internals>:177(can_cast)
#   1195287    0.320    0.000    0.418    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\generic.py:30(_check)
#   1193556    0.427    0.000    0.895    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:238(nnz)
#   1193556    0.468    0.000    0.468    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:108(getnnz)
#   1132348    1.278    0.000    1.278    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\getlimits.py:647(__init__)
#    857585    0.258    0.000    0.258    0.000 {method 'lower' of 'str' objects}
#    856912    0.083    0.000    0.083    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:235(_swap)
#    827562    0.112    0.000    0.112    0.000 {built-in method builtins.issubclass}
#    734602    0.298    0.000    0.298    0.000 {built-in method numpy.array}
#    734496    0.206    0.000    0.258    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:290(<genexpr>)
#    642684    0.108    0.000    0.108    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:23(_get_dtype)
#    581476    0.162    0.000    0.162    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\getlimits.py:671(max)
#    550872    0.228    0.000    0.228    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\getlimits.py:658(min)
#    550872    1.965    0.000    5.432    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:131(get_index_dtype)
#    550872    0.224    0.000    0.224    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\_lib\_util.py:124(_prune_array)
#    550856    0.121    0.000    0.180    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:289(<genexpr>)
#    520268    0.302    0.000    1.927    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:673(__getattr__)
#    520268    0.128    0.000    0.188    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:1205(isspmatrix)
#    520268    0.067    0.000    0.067    0.000 {built-in method _operator.index}
#    489736    0.525    0.000    0.525    0.000 {built-in method numpy.empty}
#    459196    0.126    0.000    0.399    0.000 C:\Users\Computer\anaconda3\lib\abc.py:96(__instancecheck__)
#    459196    0.185    0.000    0.273    0.000 {built-in method _abc._abc_instancecheck}
#    367332    0.097    0.000    0.184    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1762(<genexpr>)
#    367301    0.166    0.000    0.504    0.000 {built-in method builtins.all}
#    367240    0.123    0.000    1.167    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:610(<genexpr>)
#    306058    0.864    0.000    0.864    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    275774    0.133    0.000    0.656    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:254(is_dtype)
#    275557    0.153    0.000    0.309    0.000 {pandas._libs.lib.is_list_like}
#    275527    0.045    0.000    0.045    0.000 {pandas._libs.lib.is_scalar}
#    275484    0.146    0.000    0.283    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1575(get_dtype)
#    275464    0.176    0.000    1.897    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1551(_is_dtype)
#    275436    1.003    0.000    2.165    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1148(prune)
#    275434    0.032    0.000    0.032    0.000 {pandas._libs.lib.is_bool}
# 244957/244951    0.039    0.000    0.039    0.000 {built-in method builtins.hash}
#    244845    0.077    0.000    0.077    0.000 {built-in method builtins.max}
#    244836    0.173    0.000    0.173    0.000 {method 'copy' of 'numpy.ndarray' objects}
#    244832    0.139    0.000    0.139    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:66(__init__)
#    244832    0.166    0.000    0.302    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:91(to_native)
#    244832    0.685    0.000    1.010    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:277(check_shape)
# 244832/214228    1.130    0.000   12.621    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:27(__init__)
#    244832    1.494    0.000    6.139    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:136(check_format)
#    244832    0.117    0.000    0.255    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:20(__init__)
#    244832    0.089    0.000    0.089    0.000 {method 'newbyteorder' of 'numpy.dtype' objects}
#    214232    0.173    0.000    0.173    0.000 {method 'astype' of 'numpy.ndarray' objects}
#    214228    0.318    0.000    0.318    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:220(isshape)
#    183732    0.263    0.000    0.761    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5467(__setattr__)
#    183724    0.063    0.000    0.088    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:322(is_hashable)
#    183720    0.094    0.000    0.136    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1769(pandas_dtype)
#    183718    0.031    0.000    0.031    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:265(mgr_locs)
#    183708    0.024    0.000    0.024    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:248(flags)
#    183689    0.037    0.000    0.037    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1588(_block)
#    183682    0.111    0.000    0.192    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:488(name)
#    183666    0.097    0.000    0.373    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1743(validate_all_hashable)
#    183666    0.191    0.000    0.565    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:538(name)
#    183638    0.068    0.000    0.486    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:54(_any)
#    183638    0.100    0.000    0.587    0.000 {method 'any' of 'numpy.ndarray' objects}
#    183635    0.029    0.000    0.029    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:233(internal_values)
#    183635    0.114    0.000    0.179    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1626(internal_values)
#    183635    0.072    0.000    0.252    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:585(_values)
#    183620    0.048    0.000    0.048    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1304(<lambda>)
#    183620    0.072    0.000    0.446    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1276(is_string_like_dtype)
#    183620    0.076    0.000    0.101    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\util\_validators.py:208(validate_bool_kwarg)
#    183619    0.161    0.000    0.415    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:263(is_dict_like)
#    153104    0.048    0.000    0.048    0.000 {method 'rpartition' of 'str' objects}
#    153039    0.102    0.000    0.150    0.000 <frozen importlib._bootstrap>:389(parent)
# 153020/91812    0.206    0.000   15.319    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:59(inner_f)
#    153019    0.022    0.000    0.022    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:3160(_ndim_dispatcher)
#    153019    0.181    0.000    0.322    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:3164(ndim)
#    153019    0.093    0.000    0.516    0.000 <__array_function__ internals>:177(ndim)
#    153017    0.107    0.000    0.107    0.000 {built-in method numpy.zeros}
#    122484    0.058    0.000    0.089    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:282(issubclass_)
#    122434    0.018    0.000    0.018    0.000 {built-in method builtins.callable}
#    122432    0.019    0.000    0.019    0.000 {method 'items' of 'dict' objects}
#    122415    0.040    0.000    0.040    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     97895    0.037    0.000    0.037    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1123(__set_sorted)
# 92318/91823    0.025    0.000    0.088    0.000 C:\Users\Computer\anaconda3\lib\abc.py:100(__subclasscheck__)
# 92318/91823    0.063    0.000    0.063    0.000 {built-in method _abc._abc_subclasscheck}
#     92136    0.134    0.000    0.291    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1610(_is_dtype_type)
#     92088    0.063    0.000    0.088    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:411(find)
#     92084    0.091    0.000    0.201    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1470(is_extension_array_dtype)
#     91919    0.051    0.000    0.260    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:537(is_categorical_dtype)
#     91917    0.084    0.000    0.437    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:463(is_period_dtype)
#     91909    0.061    0.000    0.348    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:499(is_interval_dtype)
#     91906    0.031    0.000    0.031    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:24(_kind_name)
#     91906    0.033    0.000    0.033    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:314(_name_includes_bit_suffix)
#     91906    0.148    0.000    0.223    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:328(_name_get)
#     91903    0.024    0.000    0.036    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:195(<lambda>)
#     91903    0.020    0.000    0.020    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:190(classes_and_not_datetimelike)
#     91896    0.090    0.000    0.344    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:923(is_dtype)
#     91888    0.063    0.000    0.279    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:1132(is_dtype)
#     91870    0.198    0.000    0.403    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:127(__init__)
#     91870    0.039    0.000    0.039    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:161(_check_ndim)
#     91870    0.047    0.000    0.055    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:269(mgr_locs)
#     91859    0.068    0.000    0.068    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\flags.py:47(__init__)
#     91859    0.210    0.000    0.278    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:188(__init__)
#     91854    0.017    0.000    0.017    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\flags.py:51(allows_duplicate_labels)
#     91854    0.066    0.000    0.066    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\flags.py:83(allows_duplicate_labels)
#     91854    0.027    0.000    0.027    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:227(attrs)
#     91854    0.380    0.000    0.826    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5411(__finalize__)
#     91854    0.144    0.000    0.563    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:288(make_block_same_class)
#     91853    0.081    0.000    0.081    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5449(__getattr__)
#     91849    0.076    0.000    0.097    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1545(__init__)
#     91849    0.127    0.000    1.110    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:238(__init__)
#     91844    0.090    0.000    1.613    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:573(is_string_dtype)
#     91844    0.764    0.000    1.332    0.000 {pandas._libs.lib.infer_dtype}
#     91833    0.041    0.000    0.052    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2515(_maybe_coerce_values)
#     91822    0.014    0.000    0.014    0.000 {built-in method numpy.asanyarray}
#     91819    0.041    0.000    3.300    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:50(isna)
#     91819    0.122    0.000    3.259    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:133(_isna)
#     91818    0.175    0.000    0.347    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1617(construct_1d_object_array_from_listlike)
#     91816    0.110    0.000    0.730    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:752(copy)
#     91816    0.083    0.000    0.116    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2748(extend_blocks)
#     91816    0.092    0.000    1.259    0.000 {built-in method builtins.any}
#     91815    0.012    0.000    0.012    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:422(_constructor)
#     91815    0.028    0.000    0.028    0.000 {method 'replace' of 'str' objects}
#     91813    0.090    0.000    0.401    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1234(is_numeric_dtype)
#     91813    0.100    0.000    0.306    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5522(_protect_consolidate)
#     91813    0.072    0.000    0.190    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5538(f)
#     91813    0.066    0.000    0.371    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5534(_consolidate_inplace)
#     91813    0.040    0.000    0.054    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:975(consolidate)
#     91812    0.017    0.000    0.017    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:405(<dictcomp>)
#     91812    0.359    0.000   10.339    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:376(apply)
#     91812    0.020    0.000    0.020    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csc.py:230(_swap)
#     91812    0.055    0.000    0.055    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     91811    0.127    0.000    0.836    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1071(is_numeric_v_string_like)
#     91810    0.062    0.000    1.390    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:602(condition)
#     91810    0.070    0.000    1.328    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:605(is_excluded_dtype)
#     91810    0.109    0.000    0.218    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1566(from_blocks)
#     91809    0.056    0.000    0.138    0.000 C:\Users\Computer\anaconda3\lib\typing.py:768(__instancecheck__)
#     91809    0.057    0.000    0.082    0.000 C:\Users\Computer\anaconda3\lib\typing.py:771(__subclasscheck__)
#     91809    0.024    0.000    0.206    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:134(is_re)
#     91809    0.202    0.000    2.968    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:202(_isna_ndarraylike)
#     91809    0.281    0.000    0.875    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:244(_isna_string_dtype)
#     91809    0.159    0.000    1.663    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:840(infer_dtype_from_array)
#     91809    0.066    0.000    0.181    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1749(convert_scalar_for_putitemlike)
#     91809    0.093    0.000    0.115    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1780(validate_numeric_casting)
#     91809    1.401    0.000    7.691    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\missing.py:26(mask_missing)
#     91809    0.054    0.000    0.206    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:429(size)
#     91809    0.562    0.000   14.702    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:6489(replace)
#     91809    0.321    0.000    9.216    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:759(replace)
#     91809    0.012    0.000    0.012    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2602(_can_hold_element)
#     91809    0.123    0.000    9.594    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2605(replace)
#     91809    0.049    0.000    0.255    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2624(_should_use_regex)
#     91809    0.178    0.000   10.894    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:648(replace)
#     91809    0.014    0.000    0.014    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1634(is_consolidated)
#     91809    0.140    0.000   14.842    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4499(replace)
#     91809    0.301    0.000    0.301    0.000 {built-in method pandas._libs.missing.isnaobj}
#     61844    0.023    0.000    0.087    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:49(_preprocess)
#     61844    0.550    0.000    0.550    0.000 {method 'findall' of 're.Pattern' objects}
#     61374    0.016    0.000    0.016    0.000 {method 'get' of 'dict' objects}
#     61302    0.019    0.000    0.019    0.000 {built-in method builtins.min}
#     61242    0.068    0.000    0.163    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:356(issubdtype)
#     61219    0.060    0.000    0.060    0.000 {method 'extend' of 'list' objects}
#     61213    0.008    0.000    0.008    0.000 {method 'keys' of 'dict' objects}
#     61212    0.017    0.000    0.017    0.000 {method 'copy' of 'dict' objects}
#     61210    0.037    0.000    0.037    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:70(<dictcomp>)
#     61210    0.102    0.000    0.408    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:69(_wrapreduction)
#     61209    0.006    0.000    0.006    0.000 {method 'values' of 'dict' objects}
#     61208    0.065    0.000    0.138    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numeric.py:1859(isscalar)
#     61208    0.046    0.000    0.382    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:51(_wrapfunc)
#     61208    0.010    0.000    0.010    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2155(_sum_dispatcher)
#     61208    0.079    0.000    0.495    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2160(sum)
#     61208    0.040    0.000    0.583    0.000 <__array_function__ internals>:177(sum)
#     61208    0.029    0.000    0.046    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\_config.py:14(get_config)
#     61208    0.015    0.000    0.015    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:290(__len__)
#     61208    0.043    0.000    0.073    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:20(upcast)
#     61208    0.046    0.000    0.208    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:193(isscalarlike)
#     61208    0.106    0.000    0.259    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:198(isintlike)
#     61208    0.017    0.000    0.024    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:250(isdense)
#     61208    0.031    0.000    0.038    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1083(__set_has_canonical_format)
#     61208    0.083    0.000    0.272    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1107(__get_sorted)
#     61208    0.066    0.000    0.591    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1139(sort_indices)
#     61208    0.134    0.000    3.186    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1204(_with_data)
#     61208    0.035    0.000    0.122    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:355(_compatible_boolean_index)
#     61208    0.395    0.000    1.367    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:83(_assert_all_finite)
#     61208    0.187    0.000    0.521    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:187(_num_samples)
#     61208    0.215    0.000    5.991    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:303(_ensure_sparse_format)
#     61208    0.073    0.000    0.136    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:397(_ensure_no_complex_data)
#     61208    0.336    0.000    7.636    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:404(check_array)
#     61208    0.010    0.000    0.010    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:688(_check_large_sparse)
#     61208    0.111    0.000    0.857    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\extmath.py:663(_safe_accumulator_op)
#     61208    0.150    0.000    3.721    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:75(_analyze)
#     61208    0.039    0.000    0.046    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:191(decode)
#     61208    0.176    0.000    0.176    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:226(<listcomp>)
#     61208    1.559    0.000    2.889    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:222(_word_ngrams)
#     61208    0.089    0.000    0.089    0.000 {built-in method scipy.sparse._sparsetools.csr_has_sorted_indices}
#     61208    0.265    0.000    0.265    0.000 {method 'extend' of 'array.array' objects}
#     61206    0.391    0.000    0.391    0.000 <ipython-input-2-656193f1b223>:21(<listcomp>)
#     61206    0.091    0.000    0.729    0.000 <ipython-input-2-656193f1b223>:17(remove_punctuations)
#     36687    0.238    0.000    0.238    0.000 {built-in method scipy.sparse._sparsetools.csr_sort_indices}
#     30636    0.005    0.000    0.005    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:1071(copyto)
#     30636    0.024    0.000    0.095    0.000 <__array_function__ internals>:177(copyto)
# 30625/30622    0.016    0.000    0.016    0.000 {built-in method builtins.iter}
#     30614    0.030    0.000    0.043    0.000 C:\Users\Computer\anaconda3\lib\re.py:289(_compile)
#     30609    0.075    0.000    0.186    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:796(__iter__)
#     30609    0.091    0.000    0.091    0.000 {method 'take' of 'numpy.ndarray' objects}
#     30608    1.001    0.000    1.001    0.000 {built-in method builtins.sorted}
#     30607    0.015    0.000    0.057    0.000 C:\Users\Computer\anaconda3\lib\re.py:250(compile)
#     30607    0.006    0.000    0.006    0.000 {built-in method builtins.id}
#     30606    0.014    0.000    0.134    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:38(_amax)
#     30606    0.021    0.000    0.155    0.000 {method 'max' of 'numpy.ndarray' objects}
#     30605    0.004    0.000    0.004    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:883(bincount)
#     30605    0.027    0.000    0.129    0.000 <__array_function__ internals>:177(bincount)
#     30605    0.037    0.000    0.177    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numeric.py:149(ones)
#     30605    0.073    0.000    0.073    0.000 {method 'split' of 'str' objects}
#     30604    0.005    0.000    0.005    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:341(where)
#     30604    0.004    0.000    0.004    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:80(empty_like)
#     30604    0.004    0.000    0.004    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:1368(may_share_memory)
#     30604    0.019    0.000    0.042    0.000 <__array_function__ internals>:177(empty_like)
#     30604    0.022    0.000    0.074    0.000 <__array_function__ internals>:177(where)
#     30604    0.021    0.000    0.369    0.000 <__array_function__ internals>:177(may_share_memory)
#     30604    0.004    0.000    0.004    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:1008(_argsort_dispatcher)
#     30604    0.025    0.000    0.196    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:1012(argsort)
#     30604    0.005    0.000    0.005    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2491(_cumsum_dispatcher)
#     30604    0.029    0.000    0.240    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2495(cumsum)
#     30604    0.009    0.000    0.074    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:42(_amin)
#     30604    0.020    0.000    0.237    0.000 <__array_function__ internals>:177(argsort)
#     30604    0.022    0.000    0.287    0.000 <__array_function__ internals>:177(cumsum)
#     30604    0.004    0.000    0.004    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:167(tocsr)
#     30604    0.109    0.000    1.625    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:135(transpose)
#     30604    0.038    0.000    2.428    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:294(asformat)
#     30604    0.083    0.000    6.511    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:453(__mul__)
#     30604    0.027    0.000    6.664    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:556(__matmul__)
#     30604    0.030    0.000    0.065    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:1191(_process_toarray_args)
#     30604    0.042    0.000    2.508    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:322(_get_sliceXarray)
#     30604    0.008    0.000    0.011    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:335(isspmatrix_csr)
#     30604    0.032    0.000    0.130    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:125(_set_self)
#     30604    0.315    0.000    6.326    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:496(_mul_sparse_matrix)
#     30604    0.024    0.000    0.024    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:703(_major_slice)
#     30604    0.253    0.000    2.442    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:735(_minor_index_fancy)
#     30604    0.095    0.000    0.229    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1028(toarray)
#     30604    0.057    0.000    0.194    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1061(__get_has_canonical_format)
#     30604    0.082    0.000    0.963    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1091(sum_duplicates)
#     30604    0.024    0.000    0.992    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:30(_deduped_data)
#     30604    0.068    0.000    2.706    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:68(astype)
#     30604    0.030    0.000    1.654    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:91(copy)
#     30604    0.064    0.000    3.656    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:32(__getitem__)
#     30604    0.093    0.000    1.070    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:127(_validate_indices)
#     30604    0.073    0.000    0.320    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:151(_asindices)
#     30604    0.158    0.000    0.387    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:246(_unpack_index)
#     30604    0.035    0.000    0.038    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:292(_check_ellipsis)
#     30604    0.024    0.000    0.029    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:331(_maybe_bool_ndarray)
#     30604    0.030    0.000    0.045    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:340(_first_element_bool)
#     30604    0.251    0.000    2.379    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csc.py:134(tocsr)
#     30604    0.074    0.000    3.711    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:1843(normalize)
#     30604    0.083    0.000    7.005    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\extmath.py:118(safe_sparse_dot)
#     30604    0.054    0.000    0.078    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:40(_return_float_dtype)
#     30604    0.073    0.000    4.460    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:64(check_pairwise_arrays)
#     30604    0.103    0.000   17.070    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1145(cosine_similarity)
#     30604    0.007    0.000    0.007    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:175(_check_stop_list)
#     30604    0.031    0.000    0.031    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:304(build_preprocessor)
#     30604    0.045    0.000    0.101    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:332(build_tokenizer)
#     30604    0.014    0.000    0.021    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:352(get_stop_words)
#     30604    0.020    0.000    0.030    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:362(_check_stop_words_consistency)
#     30604    0.088    0.000    0.276    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:399(build_analyzer)
#     30604    0.016    0.000    0.016    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:439(_validate_vocabulary)
#     30604    0.019    0.000    0.019    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:477(_validate_params)
#     30604    0.058    0.000    0.202    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:800(_document_frequency)
#     30604    1.013    0.000    2.146    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1042(_sort_features)
#     30604    1.642    0.000    6.049    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1056(_limit_features)
#     30604    1.939    0.000    8.655    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1097(_count_vocab)
#     30604    0.313    0.000   17.315    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1173(fit_transform)
#     30604    0.032    0.000    0.032    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1309(_make_int_array)
#     30604    0.099    0.000   34.485    0.001 <ipython-input-2-656193f1b223>:94(check_plagiarism)
#     30604    0.197    0.000    0.201    0.000 {sklearn.utils.sparsefuncs_fast.inplace_csr_row_normalize_l2}
#     30604    0.077    0.000    0.077    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat_maxnnz}
#     30604    0.100    0.000    0.100    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat}
#     30604    0.055    0.000    0.055    0.000 {built-in method scipy.sparse._sparsetools.csr_todense}
#     30604    0.047    0.000    0.047    0.000 {built-in method scipy.sparse._sparsetools.csr_sum_duplicates}
#     30604    0.075    0.000    0.075    0.000 {built-in method scipy.sparse._sparsetools.csr_column_index1}
#     30604    0.063    0.000    0.063    0.000 {built-in method scipy.sparse._sparsetools.csr_column_index2}
#     30604    0.041    0.000    0.041    0.000 {built-in method scipy.sparse._sparsetools.csr_has_canonical_format}
#     30604    0.108    0.000    0.108    0.000 {built-in method scipy.sparse._sparsetools.csc_tocsr}
#     30604    0.144    0.000    0.144    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     30604    0.179    0.000    0.179    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#     30604    0.016    0.000    0.089    0.000 {method 'min' of 'numpy.ndarray' objects}
#     30604    0.034    0.000    0.034    0.000 {built-in method numpy.frombuffer}
#     30603    0.168    0.000   17.095    0.001 <ipython-input-2-656193f1b223>:32(clean_text)
#     30603    0.039    0.000    0.572    0.000 <ipython-input-2-656193f1b223>:43(clean_text_vi)
#     30603    0.085    0.000   34.569    0.001 <ipython-input-2-656193f1b223>:99(show_result)
#     30603    1.514    0.000    1.635    0.000 <ipython-input-2-656193f1b223>:27(<listcomp>)
#     30603    0.048    0.000    1.787    0.000 <ipython-input-2-656193f1b223>:23(remove_stopwords)
#       359    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:164(__getitem__)
#       308    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\weakref.py:422(__contains__)
#       248    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\_collections_abc.py:392(__subclasshook__)
#       233    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:187(<lambda>)
#       233    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:185(classes)
#       209    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#       178    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:201(is_object_dtype)
#       176    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\_collections_abc.py:252(__subclasshook__)
#       163    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:233(__next)
#       156    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\weakref.py:382(__getitem__)
#       131    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:254(get)
#       119    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#       115    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:160(__len__)
#       103    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#       103    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:172(append)
#       103    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#        94    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:129(cast_scalar_indexer)
#        92    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:64(<listcomp>)
#        92    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:62(_path_join)
#        92    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:388(is_datetime64tz_dtype)
#     88/44    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:145(postorderWalk)
#        76    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:249(match)
#        75    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:208(<genexpr>)
#        74    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#        72    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:347(dtype)
#        70    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        70    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#        69    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:600(__len__)
#        69    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:747(__len__)
#        69    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        67    0.000    0.000    0.004    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#        66    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#        61    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\weakref.py:395(__setitem__)
#        61    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4279(__getitem__)
#        60    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1379(maybe_cast_to_datetime)
#        60    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\base.py:111(_event_descriptors)
#        60    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#        59    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:429(is_timedelta64_dtype)
#        57    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4070(_values)
#        57    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:158(_assign_cls_collection)
#        57    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:164(update_subclass)
#        57    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:222(__init__)
#        56    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1273(maybe_infer_to_datetimelike)
#        56    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:354(extract_array)
#        54    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:286(tell)
#        54    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:912(is_datetime64_any_dtype)
#        54    0.000    0.000    0.003    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5836(ensure_index)
#        54    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:89(ophelper)
#        50    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:111(__init__)
#        49    0.003    0.000    0.003    0.000 {built-in method nt.stat}
#        48    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:80(_path_stat)
#        48    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:703(is_integer_dtype)
#        48    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1615(dtype)
#        48    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:473(dtype)
#     46/11    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\sre_parse.py:174(getwidth)
#        46    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5953(maybe_extract_name)
#        45    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:165(_get_db)
#        45    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:231(is_sparse)
#        45    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2672(get_block_type)
#        45    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_iscased}
#        44    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#        43    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:582(<listcomp>)
#        42    0.000    0.000    0.003    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3783(_get_item_cache)
#        42    0.000    0.000    0.000    0.000 {built-in method nt.fspath}
#      40/5    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\sre_compile.py:71(_compile)
#        39    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:863(__enter__)
#        39    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:867(__exit__)
#        39    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:439(_set_axis)
#        38    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:440(_colnames_from_description)
#        38    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:597(_merge_cols_by_none)
#        38    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FFCCED6B810}
#        37    0.000    0.000    0.004    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:1013(items)
#        37    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:147(_maybe_coerce_values)
#        37    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:157(blknos)
#        36    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:51(_unpack_uint32)
#        36    0.001    0.000    0.016    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:423(sanitize_array)
#        36    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        36    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#        35    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py:164(_is_all_dates)
#        35    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:173(blklocs)
#        34    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1307(is_float_dtype)
#        34    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1257(maybe_castable)
#        34    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:554(_try_cast)
#        34    0.000    0.000    0.000    0.000 {built-in method _sre.unicode_tolower}
#        33    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1875(is_floating)
#        33    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3036(get_loc)
#        33    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5287(_maybe_cast_indexer)
#        33    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#        32    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1341(is_bool_dtype)
#        32    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3306(_box_col_values)
#        32    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3409(_set_as_cached)
# ...
#         1    0.000    0.000    0.002    0.002 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:367(initialize)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:422(_check_max_identifier_length)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:434(get_default_isolation_level)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:530(type_descriptor)
#         1    0.000    0.000    2.060    2.060 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:557(connect)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1025(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:894(_init_compiled)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:206(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:231(set_parser)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:372(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:920(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:931(_create_option_mappings)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:947(set_conflict_handler)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:952(set_description)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:1178(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:1230(_create_option_list)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:1235(_add_help_option)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:1245(_populate_option_list)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:1255(_init_parsing_state)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\optparse.py:1264(set_usage)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:40(set_use_numexpr)
#         1    0.092    0.092   52.379   52.379 <ipython-input-2-656193f1b223>:108(check_plagiarism_soft)
#         1    0.001    0.001   52.389   52.389 <ipython-input-2-656193f1b223>:150(show_final_result)
#         1    0.002    0.002    2.488    2.488 <ipython-input-2-656193f1b223>:71(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:241(_detect_charset)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2722(_set_mariadb)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:107(supports_server_side_cursors)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:123(on_connect)
#         1    0.000    0.000    0.008    0.008 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2875(initialize)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:3336(_detect_ansiquotes)
#         1    0.000    0.000    0.005    0.005 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:3321(_detect_sql_mode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2686(_parse_server_version)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:3278(_detect_casing)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2903(_warn_for_known_db_issues)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2635(get_isolation_level)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2672(_get_server_version_info)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2808(_get_default_schema_name)
#         1    0.000    0.000    0.000    0.000 <string>:1(_generated_cache_key_traversal)
#         1    0.000    0.000    2.060    2.060 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\__init__.py:119(Connect)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:51(Connection)
#         1    0.000    0.000    0.002    0.002 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:296(set_character_set)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:236(autocommit)
#         1    2.053    2.053    2.055    2.055 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:56(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:190(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:187(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:345(CursorStoreResultMixIn)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:411(CursorUseResultMixIn)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:458(CursorTupleRowsMixIn)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:465(CursorDictRowsMixIn)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:472(Cursor)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:477(DictCursor)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:482(SSCursor)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:487(SSDictCursor)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:1(<module>)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\converters.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\constants\FLAG.py:1(<module>)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:387(collapseDuplicateSubtrees)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:413(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:427(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:409(optimizeTemporariesAllocation)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:450(setRegisterNumbersForTemporaries)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:483(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:474(convertASTtoThreeAddrForm)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:505(quadrupleToString)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:512(toString)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:525(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:487(compileThreeAddrForm)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:558(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:601(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\utils.py:116(_init_num_threads)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\utils.py:207(CacheDict)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\utils.py:11(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\version.py:2(<module>)
#         1    0.000    0.000    0.000    0.000 <expr>:1(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:231(Register)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:260(Immediate)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:309(isReduction)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:354(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:345(getConstants)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:380(assignBranchRegisters)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:554(precompile)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:607(NumExpr)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:723(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:708(getExprNames)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:11(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\utils.py:98(set_num_threads)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:80(ASTNode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:393(ExpressionNode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:482(LeafNode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:486(VariableNode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:493(RawNode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:512(ConstantNode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:529(OpNode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:538(FuncNode)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:11(<module>)
#         1    0.000    0.000    0.014    0.014 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:1(<module>)
#         1    0.000    0.000    0.013    0.013 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\check.py:1(<module>)
#         1    0.000    0.000    0.010    0.010 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\__init__.py:11(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\__config__.py:3(<module>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:53(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:52(Expression)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\expressions.py:69(Context)
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#         1    0.001    0.001    0.001    0.001 {pandas._libs.algos.take_2d_axis1_int64_int64}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.map_infer}
#         1    0.000    0.000    0.000    0.000 {method 'unique' of 'pandas._libs.hashtable.PyObjectHashTable' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.hashtable.ismember_object}
#         1    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 {built-in method nt.getcwd}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'setdefault' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.chr}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#         1    0.003    0.003    0.003    0.003 {built-in method _imp.create_dynamic}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.exec_dynamic}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.001    0.001    0.001    0.001 {built-in method pandas._libs.json.dumps}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op}
#         1    0.000    0.000    0.000    0.000 {function Connection.autocommit at 0x000002ABB5CC0EE0}
#         1    0.000    0.000    0.000    0.000 {method 'get_autocommit' of '_mysql.connection' objects}
#         1    0.000    0.000    0.000    0.000 {function Connection.set_character_set at 0x000002ABB5CC5310}
#         1    0.000    0.000    0.000    0.000 {method 'get_server_info' of '_mysql.connection' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numexpr.interpreter._set_num_threads}

# %%
def main():
    start = time.time()
    parser = optparse.OptionParser()

    # add options
#     parser.add_option('-v','--version', dest = 'version',
#                       type = 'string',
#                       help = 'choose english or vietnamese version')
#     parser.add_option('-t','--testid', dest = 'testid',
#                       type = 'string',
#                       help = 'please enter the test id')
#     parser.add_option('-s','--score', dest = 'score',
#                       type = 'string',
#                       help = 'please enter the algorithm score')


#     (options, args) = parser.parse_args()
#     if (options.version == None):
#             print ("Version is not null")
#             exit(0)
#     else:
#             version = options.version

#     if (options.testid == None):
#             print ("Test id is not null")
#             exit(0)
#     else:
#             testid = options.testid

#     if (options.score == None):
#             print ("The score is not null")
#             exit(0)
#     else:
#             score = options.score
    my_checker = Checker('vie2010','0.3','199107')
    print(my_checker.version)
    print(my_checker.score)
    print(my_checker.test_id)
    print(my_checker.show_final_result())

    end = time.time()
    print("It takes: ",end -start)


if __name__ == "__main__":
#     import cProfile, pstats
#     profiler = cProfile.Profile()
#     profiler.enable()
    main()
#     profiler.disable()
#     stats = pstats.Stats(profiler).sort_stats('cumtime')
#     stats.print_stats()
# Out:
# vie2010
# 0.3
# 199107
# ---------------------------------------------------------------------------
# BrokenProcessPool                         Traceback (most recent call last)
# <ipython-input-13-905461cd680a> in <module>
#      47 #     profiler = cProfile.Profile()
#      48 #     profiler.enable()
# ---> 49     main()
#      50 #     profiler.disable()
#      51 #     stats = pstats.Stats(profiler).sort_stats('cumtime')
#
# <ipython-input-13-905461cd680a> in main()
#      37     print(my_checker.score)
#      38     print(my_checker.test_id)
# ---> 39     print(my_checker.show_final_result())
#      40
#      41     end = time.time()
#
# <ipython-input-11-0595df672f15> in show_final_result(self)
#     151     def show_final_result(self):
#     152         #result = self.check_plagiarism_soft(self.test_file,self.s_vector)
# --> 153         result = self.check_plagiarism_soft(self.test_file,self.text,self.verses_id)
#     154         result_model = pd.read_sql_query(f"select verses.id,verses.book_id,verses.chapter,verses.number,verses.text from verses where verses.id={result[0]}", self.engine)
#     155         result_model['score'] = result[1]
#
# <ipython-input-11-0595df672f15> in check_plagiarism_soft(self, test_file, text, verses_id)
#     144
#     145         #     result['score'] = score
# --> 146         dt = pd.DataFrame(result)
#     147         result_file =[dt.loc[dt['score']==max(dt['score'])]['id'].tolist()[0],dt.loc[dt['score']==max(dt['score'])]['score'].tolist()[0]]
#     148         return result_file
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     276         keys = list(data.keys())
#     277         columns = data_names = Index(keys)
# --> 278         arrays = [com.maybe_iterable_to_list(data[k]) for k in keys]
#     279         # GH#24096 need copy to be deep for datetime64tz case
#     280         # TODO: See if we can avoid these copies
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in <listcomp>(.0)
#     276         keys = list(data.keys())
#     277         columns = data_names = Index(keys)
# --> 278         arrays = [com.maybe_iterable_to_list(data[k]) for k in keys]
#     279         # GH#24096 need copy to be deep for datetime64tz case
#     280         # TODO: See if we can avoid these copies
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in maybe_iterable_to_list(obj)
#     257     """
#     258     if isinstance(obj, abc.Iterable) and not isinstance(obj, abc.Sized):
# --> 259         return list(obj)
#     260     # error: Incompatible return value type (got
#     261     # "Union[pandas.core.common.<subclass of "Iterable" and "Sized">,
#
# ~\anaconda3\lib\concurrent\futures\process.py in _chain_from_iterable_of_lists(iterable)
#     482     careful not to keep references to yielded objects.
#     483     """
# --> 484     for element in iterable:
#     485         element.reverse()
#     486         while element:
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result_iterator()
#     609                     # Careful not to keep a reference to the popped future
#     610                     if timeout is None:
# --> 611                         yield fs.pop().result()
#     612                     else:
#     613                         yield fs.pop().result(end_time - time.monotonic())
#
# ~\anaconda3\lib\concurrent\futures\_base.py in result(self, timeout)
#     430                 raise CancelledError()
#     431             elif self._state == FINISHED:
# --> 432                 return self.__get_result()
#     433
#     434             self._condition.wait(timeout)
#
# ~\anaconda3\lib\concurrent\futures\_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# BrokenProcessPool: A process in the process pool was terminated abruptly while the future was running or pending.

# %%
import cProfile
import pandas as pd
#import sys
from sqlalchemy import create_engine
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import spacy
from sklearn.feature_extraction.text import CountVectorizer
import string
import concurrent.futures
import time
import optparse


## Implement the string data

def remove_punctuations(txt, punct = string.punctuation):
    '''
    This function will remove punctuations from the input text
    '''
    return ''.join([c for c in txt if c not in punct])

def remove_stopwords(txt, sw = list(stopwords.words('english'))):
    '''
    This function will remove the stopwords from the input txt
    '''
    return ' '.join([w for w in txt.split() if w.lower() not in sw])


en_nlp = spacy.load('en_core_web_sm')

def clean_text(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)
    txt = remove_stopwords(txt)
    return txt.lower()

def clean_text_vi(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)

    return txt.lower()
def lemma_text(text_line):
    #test_file_clean = []
    doc_spacy = en_nlp(text_line)
    line = [ a.lemma_ for a in doc_spacy]
    #sentence = " ".join(line)
    #test_file_clean.append(sentence)
    return " ".join(line)



vectorizer1 = CountVectorizer(ngram_range=(2,4),stop_words="english")
vectorizer2 = CountVectorizer(ngram_range=(2,4),stop_words="english",min_df=0.55)

class Checker():
    ## Connect to the MySQL server
    engine = create_engine('mysql://root:kakalot123@localhost:3306/db')
    # book_id =177
    # language = 'en'
    def __init__(self,version,score,test_id):
        self.version = version
        self.score = score
        self.test_id = test_id
        if(self.version =='esv'):
            self.book_id =177
            self.language ='en'
        elif(self.version =='vie2010'):
            self.book_id =397
            self.language ='vi'
        self.train_query = """select verses.id,verses.book_id,verses.chapter,verses.number,verses.text,books.id as books_id,books.name_id,books.name,books.short_name,books.version,books.language from verses  inner join books on verses.book_id = books.id where verses.book_id!={} and books.language='{}' and books.version='{}'""".format(self.book_id,self.language,self.version)
        self.train_model = pd.read_sql_query(self.train_query, self.engine)
        # print(self.test_id)
        # print(self.version)
        # print(self.book_id)
        # print(self.language)
        self.test_query = """select verses.id,verses.book_id,verses.chapter,verses.number,verses.text,books.id as books_id,books.name_id,books.name,books.short_name,books.version,books.language from verses  inner join books on verses.book_id = books.id where verses.book_id={} and books.language='{}' and verses.id ={} and books.version='{}'""".format(self.book_id,self.language,self.test_id,self.version)
        self.test_model = pd.read_sql_query(self.test_query,self.engine).drop(['books_id','name','short_name','version','language'],axis=1)
        self.text = self.train_model['text'].tolist()
        self.verses_id = self.train_model['id'].tolist()
        self.s_vector = list(zip(self.verses_id,self.text))
        self.test_file = self.test_model['text'].apply(str)

    def check_plagiarism(self,train_file,test_file,vectorizer):
        documents = [train_file,test_file]
        sparse_matrix = vectorizer.fit_transform(documents)
        score = cosine_similarity(sparse_matrix)[0][1]
        return score
    def show_result(self,train_file,test_file):

        score = self.check_plagiarism(train_file,test_file,vectorizer1)
        if score >float(self.score):
            score = self.check_plagiarism(train_file,test_file,vectorizer2)
        return score



    def check_plagiarism_soft(self,test_file,s_vector):
    #def check_plagiarism_soft(self,test_file):
        self.test_file = test_file
#         self.text = text
#         self.verses_id = verses_id
        self.s_vector = s_vector
        result = {"id":[],"score":[]}

#         if(self.version=='esv'):
#             self.text = [clean_text(txt) for txt in self.text]
#             self.text = [lemma_text(txt) for txt in self.text ]
#             self.test_file = clean_text(self.test_file)
#             self.test_file = lemma_text(self.test_file)
#         elif(self.version =='vie2010'):
#             self.test_file = clean_text_vi(self.test_file)
#         test_file_list =[]
#         for i in range(len(self.text)):
#             test_file_list.append(self.test_file)
#         result['id'] = list(self.verses_id)
#         with concurrent.futures.ProcessPoolExecutor() as executor:
#             score = executor.map(self.show_result,self.text,test_file_list)
#         result['score'] = score

        for a,v_vector in self.s_vector:
            test_file = clean_text(self.test_file)

            if(self.version=='esv'):
                v_vector = clean_text(v_vector)
                test_file = lemma_text(test_file)
                v_vector = lemma_text(v_vector)
            elif(self.version =='vie2010'):
                v_vector = clean_text_vi(v_vector)
            score = self.show_result(v_vector,test_file)
            result['id'].append(a)
                #score.append(executor.submit(self.show_result, train_file=v_vector,test_file=test_file))
            result['score'].append(score)

        #     result['score'] = score
        dt = pd.DataFrame(result)
        result_file =[dt.loc[dt['score']==max(dt['score'])]['id'].tolist()[0],dt.loc[dt['score']==max(dt['score'])]['score'].tolist()[0]]
        return result_file


    def show_final_result(self):
        result = self.check_plagiarism_soft(self.test_file,self.s_vector)
        #result = self.check_plagiarism_soft(self.test_file)
        result_model = pd.read_sql_query(f"select verses.id,verses.book_id,verses.chapter,verses.number,verses.text from verses where verses.id={result[0]}", self.engine)
        result_model['score'] = result[1]
        df = result_model.to_json(orient='table',index=False)
        return df

def main():
    start = time.time()
    #parser = optparse.OptionParser()

    # add options
#     parser.add_option('-v','--version', dest = 'version',
#                       type = 'string',
#                       help = 'choose english or vietnamese version')
#     parser.add_option('-t','--testid', dest = 'testid',
#                       type = 'string',
#                       help = 'please enter the test id')
#     parser.add_option('-s','--score', dest = 'score',
#                       type = 'string',
#                       help = 'please enter the algorithm score')


#     (options, args) = parser.parse_args()
#     if (options.version == None):
#             print ("Version is not null")
#             exit(0)
#     else:
#             version = options.version

#     if (options.testid == None):
#             print ("Test id is not null")
#             exit(0)
#     else:
#             testid = options.testid

#     if (options.score == None):
#             print ("The score is not null")
#             exit(0)
#     else:
#             score = options.score
    my_checker = Checker('vie2010','0.3','199107')
    print(my_checker.version)
    print(my_checker.score)
    print(my_checker.test_id)
    print(my_checker.show_final_result())

    end = time.time()
    print("It takes: ",end -start)


if __name__ == "__main__":
    import cProfile, pstats
    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('cumtime')
    stats.print_stats()
# Out:
# vie2010
# 0.3
# 199107
# {"schema":{"fields":[{"name":"id","type":"integer"},{"name":"book_id","type":"integer"},{"name":"chapter","type":"integer"},{"name":"number","type":"integer"},{"name":"text","type":"string"},{"name":"score","type":"number"}],"pandas_version":"0.20.0"},"data":[{"id":199539,"book_id":398,"chapter":1,"number":1,"text":"Phao-l\u00f4, b\u1edfi \u00fd \u0111\u1ecbnh c\u1ee7a \u0110\u1ee9c Ch\u00faa Tr\u1eddi, \u0111\u01b0\u1ee3c k\u00eau g\u1ecdi l\u00e0m s\u1ee9 \u0111\u1ed3 c\u1ee7a \u0110\u1ea5ng Christ J\u00easus, c\u00f9ng v\u1edbi S\u1ed1t-then, anh em ch\u00fang ta,","score":1.0}]}
# It takes:  54.14648246765137
#          69989304 function calls (69805502 primitive calls) in 54.146 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   54.146   54.146 <ipython-input-18-999c0e58d729>:159(main)
#         1    0.001    0.001   51.889   51.889 <ipython-input-18-999c0e58d729>:151(show_final_result)
#         1    0.094    0.094   51.882   51.882 <ipython-input-18-999c0e58d729>:108(check_plagiarism_soft)
#     30603    0.085    0.000   34.243    0.001 <ipython-input-18-999c0e58d729>:99(show_result)
#     30604    0.103    0.000   34.158    0.001 <ipython-input-18-999c0e58d729>:94(check_plagiarism)
#     30604    0.306    0.000   17.098    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1173(fit_transform)
#     30603    0.172    0.000   16.984    0.001 <ipython-input-18-999c0e58d729>:32(clean_text)
#     30604    0.101    0.000   16.957    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:1145(cosine_similarity)
# 153020/91812    0.205    0.000   15.218    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:59(inner_f)
#     91809    0.140    0.000   14.713    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4499(replace)
#     91809    0.550    0.000   14.573    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:6489(replace)
# 244832/214228    1.119    0.000   12.529    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:27(__init__)
#     91809    0.177    0.000   10.810    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:648(replace)
#     91812    0.354    0.000   10.256    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:376(apply)
#     91809    0.123    0.000    9.516    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2605(replace)
#     91809    0.318    0.000    9.137    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:759(replace)
#     30604    1.920    0.000    8.573    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1097(_count_vocab)
#     91809    1.393    0.000    7.613    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\missing.py:26(mask_missing)
#     61208    0.337    0.000    7.582    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:404(check_array)
#     30604    0.082    0.000    6.964    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\extmath.py:118(safe_sparse_dot)
#     30604    0.029    0.000    6.627    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:556(__matmul__)
#     30604    0.083    0.000    6.472    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:453(__mul__)
#     30604    0.309    0.000    6.287    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:496(_mul_sparse_matrix)
#    244832    1.489    0.000    6.096    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:136(check_format)
#     61208    0.214    0.000    5.946    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:303(_ensure_sparse_format)
#     30604    1.622    0.000    5.928    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1056(_limit_features)
#    550872    1.952    0.000    5.392    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:131(get_index_dtype)
#     30604    0.072    0.000    4.419    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:64(check_pairwise_arrays)
#     30604    0.075    0.000    3.694    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:1843(normalize)
#     61208    0.149    0.000    3.675    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:75(_analyze)
#     30604    0.063    0.000    3.556    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:32(__getitem__)
#     91819    0.042    0.000    3.269    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:50(isna)
#     91819    0.121    0.000    3.227    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:133(_isna)
#     61208    0.135    0.000    3.166    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1204(_with_data)
#     91809    0.199    0.000    2.939    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:202(_isna_ndarraylike)
# 1652666/1652661    1.596    0.000    2.889    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     61208    1.548    0.000    2.858    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:222(_word_ngrams)
#     30604    0.069    0.000    2.682    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:68(astype)
#     30604    0.042    0.000    2.424    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:322(_get_sliceXarray)
#     30604    0.038    0.000    2.408    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:294(asformat)
#     30604    0.250    0.000    2.359    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csc.py:134(tocsr)
#     30604    0.251    0.000    2.358    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:735(_minor_index_fancy)
#         1    0.003    0.003    2.257    2.257 <ipython-input-18-999c0e58d729>:71(__init__)
#         3    0.012    0.004    2.254    0.751 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:326(read_sql_query)
#         3    0.000    0.000    2.242    0.747 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:1256(read_query)
#         3    0.000    0.000    2.151    0.717 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:1174(execute)
#         3    0.000    0.000    2.151    0.717 <string>:1(execute)
#         3    0.000    0.000    2.151    0.717 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:383(warned)
#         3    0.000    0.000    2.151    0.717 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3010(execute)
#    275436    0.993    0.000    2.146    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1148(prune)
#     30604    1.008    0.000    2.134    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1042(_sort_features)
#         3    0.000    0.000    2.039    0.680 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3080(connect)
#       4/3    0.000    0.000    2.039    0.680 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:63(__init__)
#         3    0.000    0.000    2.039    0.680 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3152(raw_connection)
#         3    0.000    0.000    2.039    0.680 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3138(_wrap_pool_connect)
#         3    0.000    0.000    2.039    0.680 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:293(connect)
#         3    0.000    0.000    2.039    0.680 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:752(_checkout)
#         3    0.000    0.000    2.039    0.680 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:417(checkout)
#         3    0.000    0.000    2.039    0.680 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py:118(_do_get)
#         1    0.000    0.000    2.039    2.039 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:244(_create_connection)
#         1    0.000    0.000    2.039    2.039 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:359(__init__)
#         1    0.000    0.000    2.039    2.039 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:591(__connect)
#         1    0.000    0.000    2.031    2.031 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:572(connect)
#         1    0.000    0.000    2.030    2.030 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:557(connect)
#         1    0.000    0.000    2.030    2.030 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\__init__.py:119(Connect)
#         1    2.029    2.029    2.030    2.030 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:56(__init__)
#    520268    0.299    0.000    1.916    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:673(__getattr__)
# 6186252/6094437    1.101    0.000    1.890    0.000 {built-in method builtins.isinstance}
#    275464    0.173    0.000    1.880    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1551(_is_dtype)
#     30603    0.048    0.000    1.806    0.000 <ipython-input-18-999c0e58d729>:23(remove_stopwords)
#   1224164    0.596    0.000    1.690    0.000 <__array_function__ internals>:177(can_cast)
#     30603    1.531    0.000    1.654    0.000 <ipython-input-18-999c0e58d729>:27(<listcomp>)
#     30604    0.030    0.000    1.649    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:91(copy)
#     91809    0.156    0.000    1.632    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:840(infer_dtype_from_array)
#     30604    0.107    0.000    1.617    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:135(transpose)
#     91844    0.088    0.000    1.601    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:573(is_string_dtype)
#     91810    0.063    0.000    1.382    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:602(condition)
#     61208    0.388    0.000    1.352    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:83(_assert_all_finite)
#     91810    0.067    0.000    1.320    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:605(is_excluded_dtype)
#     91844    0.743    0.000    1.307    0.000 {pandas._libs.lib.infer_dtype}
#   1132348    1.270    0.000    1.270    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\getlimits.py:647(__init__)
#     91815    0.088    0.000    1.253    0.000 {built-in method builtins.any}
#    367240    0.124    0.000    1.165    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:610(<genexpr>)
#     91849    0.121    0.000    1.101    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:238(__init__)
#     30604    0.092    0.000    1.056    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:127(_validate_indices)
#    244832    0.678    0.000    0.999    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:277(check_shape)
#     30607    0.994    0.000    0.994    0.000 {built-in method builtins.sorted}
#     30604    0.024    0.000    0.979    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:30(_deduped_data)
#     30604    0.081    0.000    0.950    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1091(sum_duplicates)
#   4400104    0.913    0.000    0.913    0.000 {method 'join' of 'str' objects}
#   1193556    0.420    0.000    0.885    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:238(nnz)
#     91809    0.279    0.000    0.870    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:244(_isna_string_dtype)
#    306058    0.858    0.000    0.858    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     61208    0.111    0.000    0.852    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\extmath.py:663(_safe_accumulator_op)
#     91811    0.128    0.000    0.826    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1071(is_numeric_v_string_like)
#     91854    0.382    0.000    0.821    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5411(__finalize__)
#    183732    0.264    0.000    0.760    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5467(__setattr__)
# 2448451/2448446    0.749    0.000    0.749    0.000 {built-in method numpy.asarray}
#     91816    0.112    0.000    0.724    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:752(copy)
#     61206    0.090    0.000    0.689    0.000 <ipython-input-18-999c0e58d729>:17(remove_punctuations)
#    275774    0.131    0.000    0.657    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:254(is_dtype)
#   1316217    0.436    0.000    0.627    0.000 {built-in method builtins.hasattr}
#    183638    0.102    0.000    0.593    0.000 {method 'any' of 'numpy.ndarray' objects}
#     61208    0.065    0.000    0.579    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1139(sort_indices)
#     61208    0.041    0.000    0.577    0.000 <__array_function__ internals>:177(sum)
#    183666    0.191    0.000    0.560    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:538(name)
#     91854    0.144    0.000    0.554    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:288(make_block_same_class)
#     61844    0.538    0.000    0.538    0.000 {method 'findall' of 're.Pattern' objects}
#     30603    0.039    0.000    0.534    0.000 <ipython-input-18-999c0e58d729>:43(clean_text_vi)
#    489736    0.530    0.000    0.530    0.000 {built-in method numpy.empty}
#     61208    0.185    0.000    0.515    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:187(_num_samples)
#    153019    0.093    0.000    0.514    0.000 <__array_function__ internals>:177(ndim)
#    367301    0.162    0.000    0.500    0.000 {built-in method builtins.all}
#    183638    0.070    0.000    0.490    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:54(_any)
#     61208    0.079    0.000    0.488    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2160(sum)
#   1193556    0.465    0.000    0.465    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:108(getnnz)
#    183620    0.072    0.000    0.439    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1276(is_string_like_dtype)
#     91917    0.082    0.000    0.436    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:463(is_period_dtype)
#   1195287    0.322    0.000    0.420    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\generic.py:30(_check)
#    183619    0.160    0.000    0.412    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:263(is_dict_like)
# 4964715/4964574    0.403    0.000    0.403    0.000 {built-in method builtins.len}
#     61210    0.100    0.000    0.401    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:69(_wrapreduction)
#     91813    0.087    0.000    0.396    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1234(is_numeric_dtype)
#    459196    0.125    0.000    0.396    0.000 C:\Users\Computer\anaconda3\lib\abc.py:96(__instancecheck__)
#     91870    0.194    0.000    0.393    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:127(__init__)
#     30604    0.158    0.000    0.381    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:246(_unpack_index)
#    183666    0.096    0.000    0.369    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1743(validate_all_hashable)
#     30604    0.021    0.000    0.369    0.000 <__array_function__ internals>:177(may_share_memory)
#     91813    0.064    0.000    0.367    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5534(_consolidate_inplace)
#     61206    0.356    0.000    0.356    0.000 <ipython-input-18-999c0e58d729>:21(<listcomp>)
#     91909    0.060    0.000    0.346    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:499(is_interval_dtype)
#     91896    0.089    0.000    0.344    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:923(is_dtype)
#     91818    0.172    0.000    0.343    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1617(construct_1d_object_array_from_listlike)
#   2114194    0.282    0.000    0.326    0.000 {built-in method builtins.getattr}
#     61208    0.046    0.000    0.326    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:51(_wrapfunc)
#   4553277    0.321    0.000    0.321    0.000 {method 'append' of 'list' objects}
#    153019    0.177    0.000    0.320    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:3164(ndim)
#     30604    0.072    0.000    0.315    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:151(_asindices)
#    214228    0.314    0.000    0.314    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:220(isshape)
#     91813    0.097    0.000    0.303    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5522(_protect_consolidate)
#    244832    0.165    0.000    0.301    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:91(to_native)
#    275557    0.150    0.000    0.301    0.000 {pandas._libs.lib.is_list_like}
#    734602    0.299    0.000    0.299    0.000 {built-in method numpy.array}
#     91809    0.298    0.000    0.298    0.000 {built-in method pandas._libs.missing.isnaobj}
#     92136    0.134    0.000    0.290    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1610(_is_dtype_type)
#     30604    0.022    0.000    0.290    0.000 <__array_function__ internals>:177(cumsum)
#    275484    0.144    0.000    0.278    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1575(get_dtype)
#     91888    0.064    0.000    0.278    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:1132(is_dtype)
#     91859    0.209    0.000    0.276    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:188(__init__)
#     30604    0.087    0.000    0.273    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:399(build_analyzer)
#    459196    0.184    0.000    0.271    0.000 {built-in method _abc._abc_instancecheck}
#     61208    0.269    0.000    0.269    0.000 {method 'extend' of 'array.array' objects}
#     61208    0.081    0.000    0.266    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1107(__get_sorted)
#     91919    0.051    0.000    0.261    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:537(is_categorical_dtype)
#     61208    0.105    0.000    0.258    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:198(isintlike)
#    857524    0.257    0.000    0.257    0.000 {method 'lower' of 'str' objects}
#     91809    0.049    0.000    0.256    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2624(_should_use_regex)
#    734496    0.203    0.000    0.255    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:290(<genexpr>)
#    244832    0.117    0.000    0.255    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:20(__init__)
#    183635    0.070    0.000    0.245    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:585(_values)
#     30604    0.030    0.000    0.242    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2495(cumsum)
#     36687    0.233    0.000    0.233    0.000 {built-in method scipy.sparse._sparsetools.csr_sort_indices}
#     30604    0.094    0.000    0.226    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1028(toarray)
#    550872    0.225    0.000    0.225    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\getlimits.py:658(min)
#    550872    0.224    0.000    0.224    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\_lib\_util.py:124(_prune_array)
#     91906    0.147    0.000    0.223    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:328(_name_get)
#     91810    0.110    0.000    0.219    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1566(from_blocks)
#     61208    0.046    0.000    0.207    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:193(isscalarlike)
#     91809    0.024    0.000    0.207    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:134(is_re)
#     91809    0.054    0.000    0.202    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:429(size)
#     30604    0.058    0.000    0.200    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:800(_document_frequency)
#     30604    0.195    0.000    0.199    0.000 {sklearn.utils.sparsefuncs_fast.inplace_csr_row_normalize_l2}
#   1560804    0.197    0.000    0.197    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:80(get_shape)
#     92084    0.088    0.000    0.196    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1470(is_extension_array_dtype)
#     30604    0.057    0.000    0.192    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1061(__get_has_canonical_format)
#     91813    0.073    0.000    0.190    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5538(f)
#    183682    0.108    0.000    0.190    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:488(name)
#    520268    0.129    0.000    0.189    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:1205(isspmatrix)
#    367332    0.096    0.000    0.184    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1762(<genexpr>)
#     91809    0.067    0.000    0.182    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1749(convert_scalar_for_putitemlike)
#     30609    0.074    0.000    0.182    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:796(__iter__)
#     30604    0.180    0.000    0.180    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#    550856    0.118    0.000    0.179    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:289(<genexpr>)
#     30604    0.020    0.000    0.178    0.000 <__array_function__ internals>:177(argsort)
#    244836    0.178    0.000    0.178    0.000 {method 'copy' of 'numpy.ndarray' objects}
#     30605    0.037    0.000    0.176    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numeric.py:149(ones)
#    183635    0.110    0.000    0.175    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1626(internal_values)
#     61208    0.174    0.000    0.174    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:226(<listcomp>)
#    214232    0.174    0.000    0.174    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     61242    0.068    0.000    0.164    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:356(issubdtype)
#    581476    0.161    0.000    0.161    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\getlimits.py:671(max)
#     30606    0.020    0.000    0.151    0.000 {method 'max' of 'numpy.ndarray' objects}
#    153020    0.099    0.000    0.146    0.000 <frozen importlib._bootstrap>:389(parent)
#    244832    0.138    0.000    0.138    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:66(__init__)
#     30604    0.025    0.000    0.138    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:1012(argsort)
#     61208    0.065    0.000    0.138    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numeric.py:1859(isscalar)
#     91809    0.056    0.000    0.137    0.000 C:\Users\Computer\anaconda3\lib\typing.py:768(__instancecheck__)
#     61208    0.072    0.000    0.135    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:397(_ensure_no_complex_data)
#    183720    0.092    0.000    0.134    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1769(pandas_dtype)
#     30606    0.012    0.000    0.132    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:38(_amax)
#     30605    0.026    0.000    0.127    0.000 <__array_function__ internals>:177(bincount)
#     30604    0.032    0.000    0.127    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:125(_set_self)
#   1224164    0.119    0.000    0.119    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:498(can_cast)
#     61208    0.034    0.000    0.119    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:355(_compatible_boolean_index)
#         9    0.000    0.000    0.118    0.013 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:171(execute)
#         9    0.000    0.000    0.118    0.013 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:316(_query)
#         6    0.000    0.000    0.118    0.020 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1583(_execute_context)
#         6    0.000    0.000    0.117    0.020 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:691(do_execute)
#         5    0.000    0.000    0.117    0.023 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1463(_exec_driver_sql)
#     91809    0.094    0.000    0.116    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1780(validate_numeric_casting)
#     91816    0.084    0.000    0.116    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2748(extend_blocks)
#         4    0.000    0.000    0.114    0.028 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1102(execute)
#    827562    0.111    0.000    0.111    0.000 {built-in method builtins.issubclass}
#    153017    0.110    0.000    0.110    0.000 {built-in method numpy.zeros}
#    642684    0.106    0.000    0.106    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\data.py:23(_get_dtype)
#     30604    0.106    0.000    0.106    0.000 {built-in method scipy.sparse._sparsetools.csc_tocsr}
#    183620    0.078    0.000    0.103    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\util\_validators.py:208(validate_bool_kwarg)
#     30604    0.044    0.000    0.102    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:332(build_tokenizer)
#     30604    0.100    0.000    0.100    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat}
#     91849    0.076    0.000    0.098    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1545(__init__)
#     30636    0.024    0.000    0.094    0.000 <__array_function__ internals>:177(copyto)
#     30609    0.092    0.000    0.092    0.000 {method 'take' of 'numpy.ndarray' objects}
#    122484    0.058    0.000    0.089    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:282(issubclass_)
#    183724    0.063    0.000    0.088    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:322(is_hashable)
#    244832    0.088    0.000    0.088    0.000 {method 'newbyteorder' of 'numpy.dtype' objects}
#     30604    0.015    0.000    0.087    0.000 {method 'min' of 'numpy.ndarray' objects}
#     61208    0.087    0.000    0.087    0.000 {built-in method scipy.sparse._sparsetools.csr_has_sorted_indices}
#     30604    0.087    0.000    0.087    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     91811    0.026    0.000    0.086    0.000 C:\Users\Computer\anaconda3\lib\abc.py:100(__subclasscheck__)
#     92088    0.062    0.000    0.086    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:411(find)
#     61844    0.023    0.000    0.085    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:49(_preprocess)
#    856912    0.083    0.000    0.083    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:235(_swap)
#     91853    0.082    0.000    0.082    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5449(__getattr__)
#     91809    0.057    0.000    0.082    0.000 C:\Users\Computer\anaconda3\lib\typing.py:771(__subclasscheck__)
#     30604    0.054    0.000    0.078    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:40(_return_float_dtype)
#    244836    0.077    0.000    0.077    0.000 {built-in method builtins.max}
#     30604    0.075    0.000    0.075    0.000 {built-in method scipy.sparse._sparsetools.csr_column_index1}
#     30604    0.075    0.000    0.075    0.000 {built-in method scipy.sparse._sparsetools.csr_matmat_maxnnz}
#     30604    0.022    0.000    0.074    0.000 <__array_function__ internals>:177(where)
#         3    0.004    0.001    0.074    0.025 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:133(_wrap_result)
#     30604    0.073    0.000    0.073    0.000 {method 'split' of 'str' objects}
#     61208    0.042    0.000    0.073    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:20(upcast)
#     30604    0.009    0.000    0.073    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:42(_amin)
#         3    0.004    0.001    0.068    0.023 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:1724(from_records)
#     91859    0.068    0.000    0.068    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\flags.py:47(__init__)
#    520268    0.068    0.000    0.068    0.000 {built-in method _operator.index}
#     91854    0.066    0.000    0.066    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\flags.py:83(allows_duplicate_labels)
#     30604    0.030    0.000    0.065    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:1191(_process_toarray_args)
#     30604    0.062    0.000    0.062    0.000 {built-in method scipy.sparse._sparsetools.csr_column_index2}
#     91811    0.060    0.000    0.060    0.000 {built-in method _abc._abc_subclasscheck}
#         9    0.000    0.000    0.060    0.007 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:144(_do_get_result)
#         9    0.000    0.000    0.060    0.007 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:351(_get_result)
#         9    0.060    0.007    0.060    0.007 {method 'store_result' of '_mysql.connection' objects}
#     61216    0.058    0.000    0.058    0.000 {method 'extend' of 'list' objects}
#     30605    0.016    0.000    0.058    0.000 C:\Users\Computer\anaconda3\lib\re.py:250(compile)
#     91870    0.046    0.000    0.055    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:269(mgr_locs)
#     91812    0.054    0.000    0.054    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     30604    0.054    0.000    0.054    0.000 {built-in method scipy.sparse._sparsetools.csr_todense}
#     91813    0.040    0.000    0.054    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:975(consolidate)
#     91833    0.041    0.000    0.051    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2515(_maybe_coerce_values)
#         3    0.000    0.000    0.050    0.017 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502(to_arrays)
#         9    0.000    0.000    0.048    0.005 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:354(_post_get_result)
#         9    0.000    0.000    0.048    0.005 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:325(_fetch_row)
#         8    0.048    0.006    0.048    0.006 {method 'fetch_row' of '_mysql.result' objects}
#    153020    0.047    0.000    0.047    0.000 {method 'rpartition' of 'str' objects}
#     30604    0.047    0.000    0.047    0.000 {built-in method scipy.sparse._sparsetools.csr_sum_duplicates}
#    183620    0.046    0.000    0.046    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1304(<lambda>)
#     61208    0.038    0.000    0.046    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:191(decode)
#     61208    0.029    0.000    0.045    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\_config.py:14(get_config)
#     30604    0.029    0.000    0.044    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:340(_first_element_bool)
#     30604    0.019    0.000    0.043    0.000 <__array_function__ internals>:177(empty_like)
#    275527    0.043    0.000    0.043    0.000 {pandas._libs.lib.is_scalar}
#     30612    0.032    0.000    0.042    0.000 C:\Users\Computer\anaconda3\lib\re.py:289(_compile)
#     30604    0.040    0.000    0.040    0.000 {built-in method scipy.sparse._sparsetools.csr_has_canonical_format}
#    122415    0.040    0.000    0.040    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#    244944    0.039    0.000    0.039    0.000 {built-in method builtins.hash}
#     61208    0.031    0.000    0.038    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1083(__set_has_canonical_format)
#     91870    0.038    0.000    0.038    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:161(_check_ndim)
#     30604    0.035    0.000    0.037    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:292(_check_ellipsis)
#     61210    0.037    0.000    0.037    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:70(<dictcomp>)
#     97895    0.037    0.000    0.037    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:1123(__set_sorted)
#    183689    0.036    0.000    0.036    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1588(_block)
#     91903    0.024    0.000    0.036    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:195(<lambda>)
#         3    0.000    0.000    0.036    0.012 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:555(_list_to_arrays)
#     30604    0.033    0.000    0.033    0.000 {built-in method numpy.frombuffer}
#        29    0.033    0.001    0.033    0.001 {pandas._libs.lib.maybe_convert_objects}
#    275434    0.033    0.000    0.033    0.000 {pandas._libs.lib.is_bool}
#     30604    0.033    0.000    0.033    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:1309(_make_int_array)
#     91906    0.032    0.000    0.032    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:314(_name_includes_bit_suffix)
#     91906    0.032    0.000    0.032    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:24(_kind_name)
#    183718    0.030    0.000    0.030    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:265(mgr_locs)
#     30604    0.030    0.000    0.030    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:304(build_preprocessor)
#     30604    0.019    0.000    0.030    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:362(_check_stop_words_consistency)
#    183635    0.029    0.000    0.029    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:233(internal_values)
#     30604    0.023    0.000    0.028    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\_index.py:331(_maybe_bool_ndarray)
#     91854    0.027    0.000    0.027    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:227(attrs)
#     91811    0.027    0.000    0.027    0.000 {method 'replace' of 'str' objects}
#         3    0.000    0.000    0.026    0.009 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:713(_convert_object_array)
#         3    0.000    0.000    0.026    0.009 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:736(<listcomp>)
#        27    0.000    0.000    0.026    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:730(convert)
#    183708    0.024    0.000    0.024    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:248(flags)
#     30604    0.024    0.000    0.024    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\compressed.py:703(_major_slice)
#     61208    0.017    0.000    0.024    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\sputils.py:250(isdense)
#         4    0.000    0.000    0.022    0.006 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:62(arrays_to_mgr)
#    153019    0.022    0.000    0.022    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:3160(_ndim_dispatcher)
#     30604    0.014    0.000    0.020    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:352(get_stop_words)
#     30604    0.020    0.000    0.020    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:477(_validate_params)
#     91903    0.020    0.000    0.020    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:190(classes_and_not_datetimelike)
#     91812    0.020    0.000    0.020    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csc.py:230(_swap)
#     61208    0.019    0.000    0.019    0.000 {built-in method builtins.min}
#    122426    0.018    0.000    0.018    0.000 {method 'items' of 'dict' objects}
#    122434    0.018    0.000    0.018    0.000 {built-in method builtins.callable}
#     91854    0.017    0.000    0.017    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\flags.py:51(allows_duplicate_labels)
#     61293    0.017    0.000    0.017    0.000 {method 'get' of 'dict' objects}
#     91812    0.016    0.000    0.016    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:405(<dictcomp>)
#         3    0.000    0.000    0.016    0.005 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:994(fetchall)
#         3    0.000    0.000    0.016    0.005 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:402(_allrows)
#        36    0.001    0.000    0.016    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:423(sanitize_array)
#     61211    0.016    0.000    0.016    0.000 {method 'copy' of 'dict' objects}
#         4    0.000    0.000    0.016    0.004 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:333(_homogenize)
#     61208    0.016    0.000    0.016    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\base.py:290(__len__)
#     30604    0.016    0.000    0.016    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:439(_validate_vocabulary)
# 30620/30617    0.015    0.000    0.015    0.000 {built-in method builtins.iter}
#         3    0.015    0.005    0.015    0.005 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:410(<listcomp>)
#     91822    0.014    0.000    0.014    0.000 {built-in method numpy.asanyarray}
#         3    0.014    0.005    0.014    0.005 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:551(<listcomp>)
#     91809    0.014    0.000    0.014    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1634(is_consolidated)
#     91809    0.012    0.000    0.012    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2602(_can_hold_element)
#     91815    0.011    0.000    0.011    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:422(_constructor)
#     30604    0.009    0.000    0.011    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:335(isspmatrix_csr)
#     61208    0.010    0.000    0.010    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2155(_sum_dispatcher)
#        10    0.000    0.000    0.010    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:502(__init__)
#         1    0.000    0.000    0.010    0.010 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:241(init_dict)
#         9    0.000    0.000    0.010    0.001 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:250(query)
#         9    0.010    0.001    0.010    0.001 {function Connection.query at 0x000002ABB5CC5040}
#         3    0.010    0.003    0.010    0.003 {pandas._libs.lib.to_object_array_tuples}
#     61208    0.009    0.000    0.009    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\utils\validation.py:688(_check_large_sparse)
#         2    0.000    0.000    0.009    0.004 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:109(maybe_convert_platform)
#     61210    0.008    0.000    0.008    0.000 {method 'keys' of 'dict' objects}
#         5    0.000    0.000    0.008    0.002 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:314(__call__)
#         1    0.000    0.000    0.007    0.007 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1636(go)
#         1    0.000    0.000    0.007    0.007 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:663(first_connect)
#         1    0.000    0.000    0.007    0.007 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2875(initialize)
#     30604    0.007    0.000    0.007    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py:175(_check_stop_list)
#     61209    0.006    0.000    0.006    0.000 {method 'values' of 'dict' objects}
#         4    0.000    0.000    0.006    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1690(create_block_manager_from_arrays)
#     30607    0.006    0.000    0.006    0.000 {built-in method builtins.id}
#         4    0.000    0.000    0.006    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1733(_form_blocks)
#     30604    0.005    0.000    0.005    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2491(_cumsum_dispatcher)
#     30636    0.005    0.000    0.005    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:1071(copyto)
#     30604    0.005    0.000    0.005    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:341(where)
#         2    0.000    0.000    0.005    0.002 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1522(exec_driver_sql)
#     30605    0.004    0.000    0.004    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:883(bincount)
#     30604    0.004    0.000    0.004    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:1368(may_share_memory)
#     30604    0.004    0.000    0.004    0.000 C:\Users\Computer\anaconda3\lib\site-packages\scipy\sparse\csr.py:167(tocsr)
#         1    0.000    0.000    0.004    0.004 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:3321(_detect_sql_mode)
#         8    0.003    0.000    0.004    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1860(_stack_arrays)
#     30604    0.004    0.000    0.004    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:80(empty_like)
#     30604    0.004    0.000    0.004    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:1008(_argsort_dispatcher)
#         3    0.000    0.000    0.004    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1829(_simple_blockify)
#         1    0.000    0.000    0.003    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:2199(to_json)
#         1    0.000    0.000    0.003    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:48(to_json)
#         1    0.000    0.000    0.003    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:213(__init__)
#        42    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3783(_get_item_cache)
#     27/11    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:250(__new__)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:112(_parse_date_columns)
#        37    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:1013(items)
#         4    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:772(tolist)
#         4    0.002    0.000    0.002    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:882(__getitem__)
#         2    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\ops\common.py:50(new_method)
#         2    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:27(__eq__)
#         2    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4969(_cmp_method)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:909(_getbool_axis)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:367(initialize)
# ...
#         9    0.000    0.000    0.000    0.000 {method 'insert_id' of '_mysql.connection' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:191(count_not_none)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:214(set_axis)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_2d_axis1_object_object}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:360(is_sequence)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arrays\numpy_.py:202(__array__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:474(equals)
#         1    0.000    0.000    0.000    0.000 <string>:1(_generated_cache_key_traversal)
#         6    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:508(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:123(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:405(ensure_wrapped_if_datetimelike)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:482(_constructor)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:736(<genexpr>)
#        17    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:304(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:303(__len__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:281(<listcomp>)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:434(connection)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:240(loc)
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:253(items)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3207(_get_pool)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:268(is_null_slice)
#         3    0.000    0.000    0.000    0.000 {method 'intersection' of 'set' objects}
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py:78(_validate_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:930(soft_close)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\util.py:134(_distill_params_20)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\missing.py:64(clean_fill_method)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:581(<lambda>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1281(_get_names)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:261(fill_value)
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:649(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py:917(get)
#         6    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\compat\numpy\function.py:45(__call__)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:183(<genexpr>)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:756(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:453(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:103(iloc)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:69(_convert_params)
#         2    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         3    0.000    0.000    0.000    0.000 {method 'union' of 'sqlalchemy.cimmutabledict.immutabledict' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1622(external_values)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:326(_supports_statement_cache)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:207(start)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py:4859(__new__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:201(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5920(ensure_has_len)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:759(_validate_key_length)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:227(is_single_block)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py:149(_inc_overflow)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:933(hard_close)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1332(post_exec)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:882(<genexpr>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:182(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2722(_set_mariadb)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:353(__init__)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1324(pre_exec)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2932(_is_mysql)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         5    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\traversals.py:954(__init__)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:272(<listcomp>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5001(_index_as_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:328(__bool__)
#         3    0.000    0.000    0.000    0.000 {method 'character_set_name' of '_mysql.connection' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\weakref.py:395(__setitem__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:606(__array__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3863(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py:913(_inc_counter)
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\inspect.py:72(isclass)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:271(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3461(_can_reindex)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:628(axes)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:359(__exit__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:4954(_delete_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:230(stop)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:781(axes)
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1298(<genexpr>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:613(min_scalar_type)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2965(_prod_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:195(<genexpr>)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:397(ndim)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3304(_get_partial_string_timestamp_match_key)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\type_api.py:291(result_processor)
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get_server_info' of '_mysql.connection' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:1751(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:5333(_append_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:253(step)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:285(obj_to_write)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2903(_warn_for_known_db_issues)
#         1    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:718(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:884(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\_config\config.py:816(is_nonnegative_int)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2636(_validate_sort_keyword)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:422(_check_max_identifier_length)
#         1    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'get_autocommit' of '_mysql.connection' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\typing.py:1149(cast)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:715(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:650(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3978(_check_inplace_and_allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:356(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:317(is_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3696(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1025(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:222(external_values)

# %%
def check_plagiarism(train_file,test_file,vectorizer):
        documents = [train_file,test_file]
        sparse_matrix = vectorizer.fit_transform(documents)
        score = cosine_similarity(sparse_matrix)[0][1]
        return score

# %%
vectorizer1 = CountVectorizer(ngram_range=(2,4),stop_words="english")
vectorizer2 = CountVectorizer(ngram_range=(2,4),stop_words="english",min_df=0.55)
import time
start_time = time.time()
check_plagiarism( 'including you who are called to belong to Jesus Christ,'
,'as to zeal, a persecutor of the church; as to righteousness, under the law blameless.'
,vectorizer1)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0020012855529785156 seconds ---

# %%
def show_result(train_file,test_file):
    score = check_plagiarism(train_file,test_file,vectorizer1)
    if score >0.2:
        score = check_plagiarism(train_file,test_file,vectorizer2)
    return score

# %%
start_time = time.time()
show_result( 'including you who are called to belong to Jesus Christ,'
,'as to zeal, a persecutor of the church; as to righteousness, under the law blameless.'
)
a = time.time() - start_time
print("--- %s seconds ---" % (a))
print("--- %s seconds ---" % (a *300000))
# Out:
# --- 0.0009992122650146484 seconds ---
# --- 299.76367950439453 seconds ---

# %%
import cProfile
import pandas as pd
#import sys
from sqlalchemy import create_engine
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import spacy
from sklearn.feature_extraction.text import CountVectorizer
import string
import concurrent.futures
import time
import optparse


## Implement the string data

def remove_punctuations(txt, punct = string.punctuation):
    '''
    This function will remove punctuations from the input text
    '''
    return ''.join([c for c in txt if c not in punct])

def remove_stopwords(txt, sw = list(stopwords.words('english'))):
    '''
    This function will remove the stopwords from the input txt
    '''
    return ' '.join([w for w in txt.split() if w.lower() not in sw])


en_nlp = spacy.load('en_core_web_sm')

def clean_text(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)
    txt = remove_stopwords(txt)
    return txt.lower()

def clean_text_vi(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)

    return txt.lower()
def lemma_text(text_line):
    #test_file_clean = []
    doc_spacy = en_nlp(text_line)
    line = [ a.lemma_ for a in doc_spacy]
    #sentence = " ".join(line)
    #test_file_clean.append(sentence)
    return " ".join(line)



vectorizer1 = CountVectorizer(ngram_range=(2,4),stop_words="english")
vectorizer2 = CountVectorizer(ngram_range=(2,4),stop_words="english",min_df=0.55)

class Checker():
    ## Connect to the MySQL server
    engine = create_engine('mysql://root:kakalot123@localhost:3306/db')
    # book_id =177
    # language = 'en'
    def __init__(self,version,score,test_id):
        self.version = version
        self.score = score
        self.test_id = test_id
        if(self.version =='esv'):
            self.book_id =177
            self.language ='en'
        elif(self.version =='vie2010'):
            self.book_id =397
            self.language ='vi'
        self.train_query = """select verses.id,verses.book_id,verses.chapter,verses.number,verses.text,books.id as books_id,books.name_id,books.name,books.short_name,books.version,books.language from verses  inner join books on verses.book_id = books.id where verses.book_id!={} and books.language='{}' and books.version='{}'""".format(self.book_id,self.language,self.version)
        self.train_model = pd.read_sql_query(self.train_query, self.engine)
        # print(self.test_id)
        # print(self.version)
        # print(self.book_id)
        # print(self.language)
        self.test_query = """select verses.id,verses.book_id,verses.chapter,verses.number,verses.text,books.id as books_id,books.name_id,books.name,books.short_name,books.version,books.language from verses  inner join books on verses.book_id = books.id where verses.book_id={} and books.language='{}' and verses.id ={} and books.version='{}'""".format(self.book_id,self.language,self.test_id,self.version)
        self.test_model = pd.read_sql_query(self.test_query,self.engine).drop(['books_id','name','short_name','version','language'],axis=1)
        self.text = self.train_model['text'].tolist()
        self.verses_id = self.train_model['id'].tolist()
        self.s_vector = list(zip(self.verses_id,self.text))
        self.test_file = self.test_model['text'].apply(str)

    def check_plagiarism(self,train_file,test_file,vectorizer):
        documents = [train_file,test_file]
        sparse_matrix = vectorizer.fit_transform(documents)
        score = cosine_similarity(sparse_matrix)[0][1]
        return score
    def show_result(self,train_file,test_file):

        score = self.check_plagiarism(train_file,test_file,vectorizer1)
        if score >float(self.score):
            score = self.check_plagiarism(train_file,test_file,vectorizer2)
        return score



    #def check_plagiarism_soft(self,test_file,s_vector):
    def check_plagiarism_soft(self):
#         self.test_file = test_file
#         self.text = text
#         self.verses_id = verses_id
#         self.s_vector = s_vector
        result = {"id":[],"score":[]}

        if(self.version=='esv'):
            self.text = [clean_text(txt) for txt in self.text]
            self.text = [lemma_text(txt) for txt in self.text ]
            self.test_file = clean_text(self.test_file)
            self.test_file = lemma_text(self.test_file)
        elif(self.version =='vie2010'):
            self.test_file = clean_text_vi(self.test_file)
        test_file_list =[self.test_file for i in range(len(self.text))]
#         for i in range(len(self.text)):
#             test_file_list.append()
        result['id'] = self.verses_id
        #score = []
        with concurrent.futures.ThreadPoolExecutor() as executor:
            score= executor.map(self.show_result,self.text,test_file_list)
        result['score'] = score

#         for a,v_vector in self.s_vector:
#             test_file = clean_text(self.test_file)

#             if(self.version=='esv'):
#                 v_vector = clean_text(v_vector)
#                 test_file = lemma_text(test_file)
#                 v_vector = lemma_text(v_vector)
#             elif(self.version =='vie2010'):
#                 v_vector = clean_text_vi(v_vector)
#             score = self.show_result(v_vector,test_file)
#             result['id'].append(a)
#                 #score.append(executor.submit(self.show_result, train_file=v_vector,test_file=test_file))
#             result['score'].append(score)

        #     result['score'] = score
        dt = pd.DataFrame(result)
        result_file =[dt.loc[dt['score']==max(dt['score'])]['id'].tolist()[0],dt.loc[dt['score']==max(dt['score'])]['score'].tolist()[0]]
        return result_file


    def show_final_result(self):
        #result = self.check_plagiarism_soft(self.test_file,self.s_vector)
        result = self.check_plagiarism_soft()
        result_model = pd.read_sql_query(f"select verses.id,verses.book_id,verses.chapter,verses.number,verses.text from verses where verses.id={result[0]}", self.engine)
        result_model['score'] = result[1]
        df = result_model.to_json(orient='table',index=False)
        return df

def main():
    start = time.time()
    #parser = optparse.OptionParser()

    # add options
#     parser.add_option('-v','--version', dest = 'version',
#                       type = 'string',
#                       help = 'choose english or vietnamese version')
#     parser.add_option('-t','--testid', dest = 'testid',
#                       type = 'string',
#                       help = 'please enter the test id')
#     parser.add_option('-s','--score', dest = 'score',
#                       type = 'string',
#                       help = 'please enter the algorithm score')


#     (options, args) = parser.parse_args()
#     if (options.version == None):
#             print ("Version is not null")
#             exit(0)
#     else:
#             version = options.version

#     if (options.testid == None):
#             print ("Test id is not null")
#             exit(0)
#     else:
#             testid = options.testid

#     if (options.score == None):
#             print ("The score is not null")
#             exit(0)
#     else:
#             score = options.score
    my_checker = Checker('vie2010','0.3','199107')
    print(my_checker.version)
    print(my_checker.score)
    print(my_checker.test_id)
    print(my_checker.show_final_result())

    end = time.time()
    print("It takes: ",end -start)


if __name__ == "__main__":
    import cProfile, pstats
    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('cumtime')
    stats.print_stats()
# Out:
# vie2010
# 0.3
# 199107
# {"schema":{"fields":[{"name":"id","type":"integer"},{"name":"book_id","type":"integer"},{"name":"chapter","type":"integer"},{"name":"number","type":"integer"},{"name":"text","type":"string"},{"name":"score","type":"number"}],"pandas_version":"0.20.0"},"data":[{"id":199539,"book_id":398,"chapter":1,"number":1,"text":"Phao-l\u00f4, b\u1edfi \u00fd \u0111\u1ecbnh c\u1ee7a \u0110\u1ee9c Ch\u00faa Tr\u1eddi, \u0111\u01b0\u1ee3c k\u00eau g\u1ecdi l\u00e0m s\u1ee9 \u0111\u1ed3 c\u1ee7a \u0110\u1ea5ng Christ J\u00easus, c\u00f9ng v\u1edbi S\u1ed1t-then, anh em ch\u00fang ta,","score":1.0}]}
# It takes:  36.98989486694336
#          1108008 function calls (1107824 primitive calls) in 36.991 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   36.991   36.991 <ipython-input-40-1fc22f8ae98f>:160(main)
#         1    0.000    0.000   34.481   34.481 <ipython-input-40-1fc22f8ae98f>:152(show_final_result)
#         1    0.000    0.000   34.474   34.474 <ipython-input-40-1fc22f8ae98f>:109(check_plagiarism_soft)
#    117721   31.750    0.000   31.750    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000   31.712   31.712 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:635(__exit__)
#         1    0.000    0.000   31.712   31.712 C:\Users\Computer\anaconda3\lib\concurrent\futures\thread.py:230(shutdown)
#        10    0.000    0.000   31.712    3.171 C:\Users\Computer\anaconda3\lib\threading.py:979(join)
#        24    0.000    0.000   31.712    1.321 C:\Users\Computer\anaconda3\lib\threading.py:1017(_wait_for_tstate_lock)
#         1    0.000    0.000    2.614    2.614 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:575(map)
#         1    0.028    0.028    2.614    2.614 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:600(<listcomp>)
#     30603    0.084    0.000    2.585    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\thread.py:158(submit)
#         1    0.004    0.004    2.510    2.510 <ipython-input-40-1fc22f8ae98f>:71(__init__)
#         3    0.010    0.003    2.507    0.836 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:326(read_sql_query)
#         3    0.000    0.000    2.496    0.832 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:1256(read_query)
#         3    0.000    0.000    2.160    0.720 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:1174(execute)
#         3    0.000    0.000    2.160    0.720 <string>:1(execute)
#         3    0.000    0.000    2.159    0.720 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:383(warned)
#         3    0.000    0.000    2.159    0.720 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3010(execute)
#         3    0.000    0.000    2.047    0.682 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3080(connect)
#       4/3    0.000    0.000    2.047    0.682 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:63(__init__)
#         3    0.000    0.000    2.047    0.682 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3152(raw_connection)
#         3    0.000    0.000    2.047    0.682 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3138(_wrap_pool_connect)
#         3    0.000    0.000    2.047    0.682 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:293(connect)
#         3    0.000    0.000    2.047    0.682 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:752(_checkout)
#         3    0.000    0.000    2.047    0.682 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:417(checkout)
#         3    0.000    0.000    2.047    0.682 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py:118(_do_get)
#         1    0.000    0.000    2.047    2.047 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:244(_create_connection)
#         1    0.000    0.000    2.047    2.047 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:359(__init__)
#         1    0.000    0.000    2.047    2.047 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:591(__connect)
#         1    0.000    0.000    2.042    2.042 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:572(connect)
#         1    0.000    0.000    2.042    2.042 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:557(connect)
#         1    0.000    0.000    2.042    2.042 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\__init__.py:119(Connect)
#         1    2.041    2.041    2.042    2.042 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:56(__init__)
#     30603    0.033    0.000    1.559    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\thread.py:193(_adjust_thread_count)
#     30603    0.069    0.000    1.505    0.000 C:\Users\Computer\anaconda3\lib\threading.py:394(acquire)
#     61222    0.023    0.000    1.286    0.000 C:\Users\Computer\anaconda3\lib\threading.py:246(__enter__)
#     30613    1.257    0.000    1.257    0.000 {method '__enter__' of '_thread.lock' objects}
#     30603    0.257    0.000    0.921    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:316(__init__)
#     30614    0.637    0.000    0.664    0.000 C:\Users\Computer\anaconda3\lib\threading.py:222(__init__)
#         3    0.000    0.000    0.264    0.088 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:994(fetchall)
#         3    0.000    0.000    0.264    0.088 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:402(_allrows)
#         3    0.262    0.087    0.262    0.087 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:410(<listcomp>)
#     29424    0.070    0.000    0.166    0.000 C:\Users\Computer\anaconda3\lib\threading.py:270(wait)
#        10    0.000    0.000    0.138    0.014 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:502(__init__)
#         1    0.000    0.000    0.137    0.137 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:241(init_dict)
#         1    0.000    0.000    0.124    0.124 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:278(<listcomp>)
#         2    0.005    0.002    0.124    0.062 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:254(maybe_iterable_to_list)
#     30604    0.056    0.000    0.119    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:604(result_iterator)
#         6    0.000    0.000    0.115    0.019 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1583(_execute_context)
#         9    0.000    0.000    0.115    0.013 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:171(execute)
#         9    0.000    0.000    0.115    0.013 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:316(_query)
#         6    0.000    0.000    0.115    0.019 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:691(do_execute)
#         5    0.000    0.000    0.114    0.023 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1463(_exec_driver_sql)
#         4    0.000    0.000    0.113    0.028 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1102(execute)
#         3    0.003    0.001    0.072    0.024 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:133(_wrap_result)
#         3    0.004    0.001    0.067    0.022 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:1724(from_records)
#         9    0.000    0.000    0.063    0.007 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:144(_do_get_result)
#         9    0.000    0.000    0.063    0.007 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:351(_get_result)
#         9    0.063    0.007    0.063    0.007 {method 'store_result' of '_mysql.connection' objects}
#     30603    0.029    0.000    0.061    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:412(result)
#         3    0.000    0.000    0.050    0.017 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502(to_arrays)
#         9    0.000    0.000    0.046    0.005 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:354(_post_get_result)
#         9    0.000    0.000    0.046    0.005 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:325(_fetch_row)
#         8    0.046    0.006    0.046    0.006 {method 'fetch_row' of '_mysql.result' objects}
#         3    0.000    0.000    0.036    0.012 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:555(_list_to_arrays)
#        29    0.034    0.001    0.034    0.001 {pandas._libs.lib.maybe_convert_objects}
#     30603    0.027    0.000    0.027    0.000 C:\Users\Computer\anaconda3\lib\threading.py:81(RLock)
#         3    0.000    0.000    0.027    0.009 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:713(_convert_object_array)
#         3    0.000    0.000    0.027    0.009 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:736(<listcomp>)
#        27    0.000    0.000    0.027    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:730(convert)
#         4    0.000    0.000    0.025    0.006 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:62(arrays_to_mgr)
#     61222    0.017    0.000    0.023    0.000 C:\Users\Computer\anaconda3\lib\threading.py:249(__exit__)
#     29437    0.022    0.000    0.022    0.000 {built-in method _thread.allocate_lock}
#         4    0.000    0.000    0.019    0.005 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:333(_homogenize)
#        36    0.001    0.000    0.019    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:423(sanitize_array)
#        10    0.000    0.000    0.018    0.002 C:\Users\Computer\anaconda3\lib\threading.py:834(start)
#     29424    0.011    0.000    0.018    0.000 C:\Users\Computer\anaconda3\lib\threading.py:258(_acquire_restore)
#        10    0.000    0.000    0.018    0.002 C:\Users\Computer\anaconda3\lib\threading.py:540(wait)
#     30603    0.016    0.000    0.016    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\thread.py:46(__init__)
#         3    0.014    0.005    0.014    0.005 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:551(<listcomp>)
#     29424    0.008    0.000    0.013    0.000 C:\Users\Computer\anaconda3\lib\threading.py:261(_is_owned)
#     29424    0.009    0.000    0.012    0.000 C:\Users\Computer\anaconda3\lib\threading.py:255(_release_save)
#         2    0.000    0.000    0.011    0.005 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:109(maybe_convert_platform)
#         3    0.009    0.003    0.009    0.003 {pandas._libs.lib.to_object_array_tuples}
#         9    0.000    0.000    0.007    0.001 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:250(query)
#         9    0.007    0.001    0.007    0.001 {function Connection.query at 0x000002ABB5CC5040}
#     30609    0.006    0.000    0.006    0.000 {method '__enter__' of '_thread.RLock' objects}
#     30603    0.006    0.000    0.006    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:386(__get_result)
#        38    0.005    0.000    0.006    0.000 {pandas._libs.lib.infer_dtype}
#         4    0.000    0.000    0.005    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1690(create_block_manager_from_arrays)
#         4    0.000    0.000    0.005    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1733(_form_blocks)
#         5    0.000    0.000    0.005    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:314(__call__)
# 60852/60711    0.005    0.000    0.005    0.000 {built-in method builtins.len}
#         4    0.005    0.001    0.005    0.001 {built-in method builtins.max}
#     58824    0.005    0.000    0.005    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.005    0.005 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1636(go)
#         1    0.000    0.000    0.005    0.005 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:663(first_connect)
#         1    0.000    0.000    0.004    0.004 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2875(initialize)
#         8    0.003    0.000    0.004    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1860(_stack_arrays)
#     30604    0.003    0.000    0.003    0.000 {method 'put' of '_queue.SimpleQueue' objects}
#     30613    0.003    0.000    0.003    0.000 {method '__exit__' of '_thread.lock' objects}
#         3    0.000    0.000    0.003    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1829(_simple_blockify)
#     29412    0.003    0.000    0.003    0.000 {method 'remove' of 'collections.deque' objects}
#        12    0.003    0.000    0.003    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1617(construct_1d_object_array_from_listlike)
#     29435    0.003    0.000    0.003    0.000 {method 'release' of '_thread.lock' objects}
#     29441    0.003    0.000    0.003    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.003    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:2199(to_json)
#         1    0.000    0.000    0.003    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:48(to_json)
#     30605    0.002    0.000    0.002    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.002    0.002 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:213(__init__)
#         2    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1522(exec_driver_sql)
#        42    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3783(_get_item_cache)
#     27/11    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:250(__new__)
#     30609    0.002    0.000    0.002    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.002    0.002 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:3321(_detect_sql_mode)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:112(_parse_date_columns)
# 4492/4483    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#        37    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:1013(items)
#        43    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:238(__init__)
#         1    0.002    0.002    0.002    0.002 <ipython-input-40-1fc22f8ae98f>:123(<listcomp>)
#         6    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1861(_soft_close)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1773(_fetchall_impl)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:971(fetchall)
#         4    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:641(do_rollback)
#         4    0.001    0.000    0.001    0.000 {method 'rollback' of '_mysql.connection' objects}
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:3278(_detect_casing)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1039(close)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:1000(close)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:852(_checkin)
#         4    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:772(tolist)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:615(_finalize_fairy)
#         4    0.001    0.000    0.001    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py:309(_execute_on_connection)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1341(_execute_clauseelement)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:867(_reset)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3601(select_dtypes)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:882(__getitem__)
#        54    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5836(ensure_index)
#         2    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\ops\common.py:50(new_method)
#         2    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:27(__eq__)
#         2    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4969(_cmp_method)
#         5    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1844(_multi_blockify)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:909(_getbool_axis)
#        60    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1379(maybe_cast_to_datetime)
#        45    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2672(get_block_type)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3591(_take_with_is_copy)
#        34    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:554(_try_cast)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:367(initialize)
#         2    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:1092(_getitem_axis)
#         9    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:2987(__getitem__)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3492(take)
#        32    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:998(iget)
#       356    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:254(is_dtype)
#         4    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1260(reindex_indexer)
#        16    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2721(make_block)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1454(take)
#        84    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#        56    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1273(maybe_infer_to_datetimelike)
#      1809    0.001    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\generic.py:30(_check)
#         1    0.000    0.000    0.001    0.001 <ipython-input-40-1fc22f8ae98f>:43(clean_text_vi)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2791(intersection)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:4178(drop)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:4124(drop)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:4160(_drop_axis)
#        12    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\algorithms.py:1661(take_nd)
#        32    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3306(_box_col_values)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4499(replace)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:6489(replace)
#         2    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:194(comparison_op)
#         6    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:376(apply)
#         2    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:2734(_construct_result)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:296(set_character_set)
#       278    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1470(is_extension_array_dtype)
#        37    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:157(blknos)
#         1    0.001    0.001    0.001    0.001 {function Connection.set_character_set at 0x000002ABB5CC5310}
#         8    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:232(_rebuild_blknos_and_blklocs)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3147(__setitem__)
#         6    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1377(_setup_result_proxy)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3231(_set_item)
#        64    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:127(__init__)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1441(_setup_dml_or_text_result)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2843(_intersection)
#       330    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1610(_is_dtype_type)
#       178    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:201(is_object_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:648(replace)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1215(__init__)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:1378(take_nd)
#       120    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5467(__setattr__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3824(_set_item)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:118(_na_arithmetic_op)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1176(insert)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\util\_decorators.py:310(wrapper)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:4157(reindex)
#       100    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:328(_name_get)
#        10    0.000    0.000    0.000    0.000 {built-in method _thread.start_new_thread}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:4564(reindex)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:218(evaluate)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2605(replace)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1311(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:98(_evaluate_numexpr)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1264(_init_metadata)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:759(replace)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1327(_slice_take_blocks_ax0)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4009(apply)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3142(get_indexer)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:157(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:652(on_connect)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:123(on_connect)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5680(dtypes)
#       111    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:463(is_period_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:1448(_getitem_tuple)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2672(_get_server_version_info)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:4011(_reindex_axes)
#       103    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:499(is_interval_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:4048(_reindex_columns)
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1577(from_array)
#       113    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:537(is_categorical_dtype)
#        31    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numeric.py:289(full)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2808(_get_default_schema_name)
#      2638    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:364(extract_index)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:2715(execution_options)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\missing.py:26(mask_missing)
#       282    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:411(find)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3180(__init__)
#        92    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:388(is_datetime64tz_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:763(_getitem_tuple_same_dim)
#        33    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3036(get_loc)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:4854(_reindex_with_indexers)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:236(autocommit)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:1479(_getitem_axis)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:288(_merge_cursor_description)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:767(evaluate)
#         1    0.000    0.000    0.000    0.000 {function Connection.autocommit at 0x000002ABB5CC0EE0}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        48    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5411(__finalize__)
#        90    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:923(is_dtype)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:417(<listcomp>)
#        82    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:1132(is_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5544(insert)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:434(get_default_isolation_level)
#        12    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\ipykernel\iostream.py:386(write)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2635(get_isolation_level)
#     56/51    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        48    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:288(make_block_same_class)
#        34    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1257(maybe_castable)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6023(_maybe_cast_data_without_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_table_schema.py:192(build_table_schema)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5566(drop)
#        32    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3409(_set_as_cached)
#        33    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5287(_maybe_cast_indexer)
#       139    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#        28    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:198(asarray_tuplesafe)
#        64    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:269(mgr_locs)
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\ipykernel\iostream.py:197(schedule)
#        53    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:188(__init__)
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:542(maybe_promote)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5947(default_index)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:659(pandasSQL_builder)
#        32    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1341(is_bool_dtype)
#        54    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:538(name)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4603(isin)
#        56    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:354(extract_array)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:1933(__array_ufunc__)
#        12    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\algorithms.py:1534(_get_take_nd_function)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4946(get_indexer_for)
#         9    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1764(is_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:231(array_ufunc)
#        26    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3025(_convert_can_do_setop)
#        13    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:50(isna)
#        32    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5889(copy)
#        13    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:133(_isna)
#        30    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#       108    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1769(pandas_dtype)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:85(__new__)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_table_schema.py:104(convert_pandas_type_to_json_field)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\threading.py:761(__init__)
#         9    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2127(inferred_type)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:2238(check_bool_indexer)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:1157(__init__)
#        32    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1335(get_result_processor)
#        33    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1875(is_floating)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:126(__init__)
#        77    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        26    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:54(_any)
#       100    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:314(_name_includes_bit_suffix)
#        46    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5953(maybe_extract_name)
#   137/132    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\zmq\sugar\socket.py:432(send)
#        61    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4279(__getitem__)
#        45    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:231(is_sparse)
#      1296    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       154    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\abc.py:96(__instancecheck__)
#        32    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\type_api.py:574(_cached_result_processor)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:266(warned)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:2694(update_execution_options)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:796(copy)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:202(_isna_ndarraylike)
#        54    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1743(validate_all_hashable)
#        16    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1090(__get__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py:508(_compile_w_cache)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1059(_init_statement)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4175(_coerce_scalar_to_index)
#         3    0.000    0.000    0.000    0.000 <string>:1(__init__)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:742(take)
#        25    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:206(shape)
#        38    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:573(is_string_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:257(get_dtypes)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:4817(reset_index)
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_asarray.py:22(require)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexers.py:363(check_array_indexer)
#        48    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:703(is_integer_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:446(checkin)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4393(equals)
#        70    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:488(name)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:310(reconstruct)
#        46    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1551(_is_dtype)
#        22    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5724(astype)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3695(<genexpr>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:72(_can_use_numexpr)
#       2/1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1654(infer_dtype_from_object)
#        34    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:356(issubdtype)
#        38    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:597(_merge_cols_by_none)
#        59    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:429(is_timedelta64_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\algorithms.py:415(isin)
#        59    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#        66    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1575(get_dtype)
#        20    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:425(_simple_new)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1951(_fast_count_smallints)
#       154    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:752(copy)
#        48    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:473(dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:303(_return_conn)
#       233    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:187(<lambda>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexers.py:225(maybe_convert_indices)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:318(_verify_integrity)
#        11    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5969(_maybe_cast_with_dtype)
#        18    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:128(nextset)
#       112    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\schema.py:4228(__init__)
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:133(_simple_new)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py:109(_do_return_conn)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:1811(unique)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\log.py:181(instance_logger)
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\base.py:317(__get__)
#        75    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:208(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:1037(unique)
#        34    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1307(is_float_dtype)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1300(create_cursor)
#       281    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#       112    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:322(is_hashable)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_table_schema.py:34(as_json_table_type)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\algorithms.py:319(unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\lib\index_tricks.py:322(__getitem__)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1199(should_autocommit)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\queue.py:91(put)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\log.py:224(__set__)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\queue.py:131(get)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:840(infer_dtype_from_array)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:602(condition)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1312(_soft_close)
# ...
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:303(__len__)
#         5    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:581(<lambda>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arrays\numpy_.py:202(__array__)
#        16    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:304(<listcomp>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:69(_convert_params)
#         1    0.000    0.000    0.000    0.000 <string>:1(_generated_cache_key_traversal)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:353(__init__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:70(<dictcomp>)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\numeric.py:78(_validate_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:474(equals)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:482(_constructor)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3284(_ensure_valid_index)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:103(iloc)
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:253(items)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:64(__iter__)
#         3    0.000    0.000    0.000    0.000 {method 'union' of 'sqlalchemy.cimmutabledict.immutabledict' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:649(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:508(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py:149(_inc_overflow)
#         2    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:268(is_null_slice)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:261(fill_value)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1622(external_values)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2722(_set_mariadb)
#         5    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         6    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py:4859(__new__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:326(_supports_statement_cache)
#         2    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\inspect.py:72(isclass)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:434(connection)
#         1    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:182(<genexpr>)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1332(post_exec)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\traversals.py:954(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:882(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:453(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:405(<dictcomp>)
#         5    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\missing.py:64(clean_fill_method)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5920(ensure_has_len)
#         9    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:422(_constructor)
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         8    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\util.py:134(_distill_params_20)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:272(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:227(is_single_block)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1324(pre_exec)
#         1    0.000    0.000    0.000    0.000 <ipython-input-40-1fc22f8ae98f>:21(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:756(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:201(<dictcomp>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:933(hard_close)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:359(__exit__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:613(min_scalar_type)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:3160(_ndim_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:183(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:207(start)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:759(_validate_key_length)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py:913(_inc_counter)
#         6    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         3    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3461(_can_reindex)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5001(_index_as_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:628(axes)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:328(__bool__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2903(_warn_for_known_db_issues)
#        10    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         3    0.000    0.000    0.000    0.000 {method 'character_set_name' of '_mysql.connection' objects}
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:498(can_cast)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:148(concatenate)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:397(ndim)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:606(__array__)
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get_server_info' of '_mysql.connection' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:195(<genexpr>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:271(<genexpr>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3304(_get_partial_string_timestamp_match_key)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2932(_is_mysql)
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:884(<genexpr>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2602(_can_hold_element)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1634(is_consolidated)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\type_api.py:291(result_processor)
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1298(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:253(step)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3863(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:285(obj_to_write)
#         1    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:356(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\typing.py:1149(cast)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2965(_prod_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:5333(_append_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2636(_validate_sort_keyword)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:230(stop)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:317(is_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:781(axes)
#         2    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get_autocommit' of '_mysql.connection' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:715(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:718(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:883(bincount)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:1751(_ravel_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\_config\config.py:816(is_nonnegative_int)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3978(_check_inplace_and_allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:422(_check_max_identifier_length)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:632(__enter__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:650(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:4954(_delete_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3696(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:222(external_values)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1025(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}

# %%
import cProfile
import pandas as pd
#import sys
from sqlalchemy import create_engine
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import spacy
from sklearn.feature_extraction.text import CountVectorizer
import string
import concurrent.futures
import time
import optparse


## Implement the string data

def remove_punctuations(txt, punct = string.punctuation):
    '''
    This function will remove punctuations from the input text
    '''
    return ''.join([c for c in txt if c not in punct])

def remove_stopwords(txt, sw = list(stopwords.words('english'))):
    '''
    This function will remove the stopwords from the input txt
    '''
    return ' '.join([w for w in txt.split() if w.lower() not in sw])


en_nlp = spacy.load('en_core_web_sm')

def clean_text(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)
    txt = remove_stopwords(txt)
    return txt.lower()

def clean_text_vi(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)

    return txt.lower()
def lemma_text(text_line):
    #test_file_clean = []
    doc_spacy = en_nlp(text_line)
    line = [ a.lemma_ for a in doc_spacy]
    #sentence = " ".join(line)
    #test_file_clean.append(sentence)
    return " ".join(line)



vectorizer1 = CountVectorizer(ngram_range=(2,4),stop_words="english")
vectorizer2 = CountVectorizer(ngram_range=(2,4),stop_words="english",min_df=0.55)

class Checker():
    ## Connect to the MySQL server
    engine = create_engine('mysql://root:kakalot123@localhost:3306/db')
    # book_id =177
    # language = 'en'
    def __init__(self,version,score,test_id):
        self.version = version
        self.score = score
        self.test_id = test_id
        if(self.version =='esv'):
            self.book_id =177
            self.language ='en'
        elif(self.version =='vie2010'):
            self.book_id =397
            self.language ='vi'
        self.train_query = """select verses.id,verses.text from verses  inner join books on verses.book_id = books.id where verses.book_id!={} and books.language='{}' and books.version='{}'""".format(self.book_id,self.language,self.version)
        self.train_model = pd.read_sql_query(self.train_query, self.engine)
        # print(self.test_id)
        # print(self.version)
        # print(self.book_id)
        # print(self.language)
        self.test_query = """select verses.id,verses.text from verses  inner join books on verses.book_id = books.id where verses.book_id={} and books.language='{}' and verses.id ={} and books.version='{}'""".format(self.book_id,self.language,self.test_id,self.version)
        self.test_model = pd.read_sql_query(self.test_query,self.engine)
        self.text = self.train_model['text'].tolist()
        self.verses_id = self.train_model['id'].tolist()
        self.s_vector = list(zip(self.verses_id,self.text))
        self.test_file = self.test_model['text'].apply(str)

    def check_plagiarism(self,train_file,test_file,vectorizer):
        documents = [train_file,test_file]
        sparse_matrix = vectorizer.fit_transform(documents)
        score = cosine_similarity(sparse_matrix)[0][1]
        return score
    def show_result(self,train_file,test_file):

        score = self.check_plagiarism(train_file,test_file,vectorizer1)
        if score >float(self.score):
            score = self.check_plagiarism(train_file,test_file,vectorizer2)
        return score



    #def check_plagiarism_soft(self,test_file,s_vector):
    def check_plagiarism_soft(self):
#         self.test_file = test_file
#         self.text = text
#         self.verses_id = verses_id
#         self.s_vector = s_vector
        result = {"id":[],"score":[]}

        if(self.version=='esv'):
            self.text = [clean_text(txt) for txt in self.text]
            self.text = [lemma_text(txt) for txt in self.text ]
            self.test_file = clean_text(self.test_file)
            self.test_file = lemma_text(self.test_file)
        elif(self.version =='vie2010'):
            self.test_file = clean_text_vi(self.test_file)
        test_file_list =[self.test_file for i in range(len(self.text))]
#         for i in range(len(self.text)):
#             test_file_list.append()
        result['id'] = self.verses_id
        #score = []
        with concurrent.futures.ThreadPoolExecutor() as executor:
            score= executor.map(self.show_result,self.text, test_file_list)
        result['score'] = score

#         for a,v_vector in self.s_vector:
#             test_file = clean_text(self.test_file)

#             if(self.version=='esv'):
#                 v_vector = clean_text(v_vector)
#                 test_file = lemma_text(test_file)
#                 v_vector = lemma_text(v_vector)
#             elif(self.version =='vie2010'):
#                 v_vector = clean_text_vi(v_vector)
#             score = self.show_result(v_vector,test_file)
#             result['id'].append(a)
#                 #score.append(executor.submit(self.show_result, train_file=v_vector,test_file=test_file))
#             result['score'].append(score)

        #     result['score'] = score
        dt = pd.DataFrame(result)
        result_file =[dt.loc[dt['score']==max(dt['score'])]['id'].tolist()[0],dt.loc[dt['score']==max(dt['score'])]['score'].tolist()[0]]
        return result_file


    def show_final_result(self):
        #result = self.check_plagiarism_soft(self.test_file,self.s_vector)
        result = self.check_plagiarism_soft()
        result_model = pd.read_sql_query(f"select verses.id,verses.book_id,verses.chapter,verses.number,verses.text from verses where verses.id={result[0]}", self.engine)
        result_model['score'] = result[1]
        df = result_model.to_json(orient='table',index=False)
        return df

def main():
    start = time.time()
    #parser = optparse.OptionParser()

    # add options
#     parser.add_option('-v','--version', dest = 'version',
#                       type = 'string',
#                       help = 'choose english or vietnamese version')
#     parser.add_option('-t','--testid', dest = 'testid',
#                       type = 'string',
#                       help = 'please enter the test id')
#     parser.add_option('-s','--score', dest = 'score',
#                       type = 'string',
#                       help = 'please enter the algorithm score')


#     (options, args) = parser.parse_args()
#     if (options.version == None):
#             print ("Version is not null")
#             exit(0)
#     else:
#             version = options.version

#     if (options.testid == None):
#             print ("Test id is not null")
#             exit(0)
#     else:
#             testid = options.testid

#     if (options.score == None):
#             print ("The score is not null")
#             exit(0)
#     else:
#             score = options.score
    my_checker = Checker('vie2010','0.3','199107')
    print(my_checker.version)
    print(my_checker.score)
    print(my_checker.test_id)
    print(my_checker.show_final_result())

    end = time.time()
    print("It takes: ",end -start)


if __name__ == "__main__":
    import cProfile, pstats
    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('cumtime')
    stats.print_stats()
# Out:
# vie2010
# 0.3
# 199107
# {"schema":{"fields":[{"name":"id","type":"integer"},{"name":"book_id","type":"integer"},{"name":"chapter","type":"integer"},{"name":"number","type":"integer"},{"name":"text","type":"string"},{"name":"score","type":"number"}],"pandas_version":"0.20.0"},"data":[{"id":199539,"book_id":398,"chapter":1,"number":1,"text":"Phao-l\u00f4, b\u1edfi \u00fd \u0111\u1ecbnh c\u1ee7a \u0110\u1ee9c Ch\u00faa Tr\u1eddi, \u0111\u01b0\u1ee3c k\u00eau g\u1ecdi l\u00e0m s\u1ee9 \u0111\u1ed3 c\u1ee7a \u0110\u1ea5ng Christ J\u00easus, c\u00f9ng v\u1edbi S\u1ed1t-then, anh em ch\u00fang ta,","score":1.0}]}
# It takes:  35.24558639526367
#          1107168 function calls (1107012 primitive calls) in 35.245 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   35.245   35.245 <ipython-input-38-29646a735120>:160(main)
#         1    0.000    0.000   33.097   33.097 <ipython-input-38-29646a735120>:152(show_final_result)
#         1    0.000    0.000   33.090   33.090 <ipython-input-38-29646a735120>:109(check_plagiarism_soft)
#    119309   30.932    0.000   30.932    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000   30.896   30.896 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:635(__exit__)
#         1    0.000    0.000   30.896   30.896 C:\Users\Computer\anaconda3\lib\concurrent\futures\thread.py:230(shutdown)
#        10    0.000    0.000   30.896    3.090 C:\Users\Computer\anaconda3\lib\threading.py:979(join)
#        24    0.000    0.000   30.896    1.287 C:\Users\Computer\anaconda3\lib\threading.py:1017(_wait_for_tstate_lock)
#         1    0.005    0.005    2.148    2.148 <ipython-input-38-29646a735120>:71(__init__)
#         3    0.004    0.001    2.146    0.715 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:326(read_sql_query)
#         3    0.000    0.000    2.142    0.714 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:1256(read_query)
#         3    0.000    0.000    2.107    0.702 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:1174(execute)
#         3    0.000    0.000    2.107    0.702 <string>:1(execute)
#         3    0.000    0.000    2.107    0.702 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:383(warned)
#         3    0.000    0.000    2.107    0.702 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3010(execute)
#         1    0.000    0.000    2.037    2.037 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:575(map)
#         1    0.027    0.027    2.037    2.037 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:600(<listcomp>)
#         3    0.000    0.000    2.028    0.676 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3080(connect)
#       4/3    0.000    0.000    2.028    0.676 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:63(__init__)
#         3    0.000    0.000    2.028    0.676 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3152(raw_connection)
#         3    0.000    0.000    2.028    0.676 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3138(_wrap_pool_connect)
#         3    0.000    0.000    2.028    0.676 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:293(connect)
#         3    0.000    0.000    2.028    0.676 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:752(_checkout)
#         3    0.000    0.000    2.028    0.676 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:417(checkout)
#         3    0.000    0.000    2.028    0.676 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py:118(_do_get)
#         1    0.000    0.000    2.028    2.028 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:244(_create_connection)
#         1    0.000    0.000    2.028    2.028 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:359(__init__)
#         1    0.000    0.000    2.028    2.028 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:591(__connect)
#         1    0.000    0.000    2.024    2.024 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:572(connect)
#         1    0.000    0.000    2.024    2.024 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:557(connect)
#         1    0.000    0.000    2.024    2.024 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\__init__.py:119(Connect)
#         1    2.023    2.023    2.024    2.024 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:56(__init__)
#     30603    0.355    0.000    2.010    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\thread.py:158(submit)
#     30603    0.027    0.000    1.058    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\thread.py:193(_adjust_thread_count)
#     30603    0.065    0.000    1.008    0.000 C:\Users\Computer\anaconda3\lib\threading.py:394(acquire)
#     61222    0.021    0.000    0.808    0.000 C:\Users\Computer\anaconda3\lib\threading.py:246(__enter__)
#     30613    0.780    0.000    0.780    0.000 {method '__enter__' of '_thread.lock' objects}
#     30603    0.435    0.000    0.436    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\thread.py:46(__init__)
#     30603    0.043    0.000    0.156    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:316(__init__)
#     29821    0.062    0.000    0.156    0.000 C:\Users\Computer\anaconda3\lib\threading.py:270(wait)
#         9    0.001    0.000    0.147    0.016 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:502(__init__)
#         1    0.000    0.000    0.146    0.146 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:241(init_dict)
#         1    0.000    0.000    0.131    0.131 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:278(<listcomp>)
#         2    0.005    0.002    0.131    0.066 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:254(maybe_iterable_to_list)
#     30605    0.060    0.000    0.126    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:604(result_iterator)
#     30614    0.086    0.000    0.113    0.000 C:\Users\Computer\anaconda3\lib\threading.py:222(__init__)
#         6    0.000    0.000    0.081    0.014 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1583(_execute_context)
#         9    0.000    0.000    0.081    0.009 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:171(execute)
#         9    0.000    0.000    0.081    0.009 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:316(_query)
#         5    0.000    0.000    0.081    0.016 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1463(_exec_driver_sql)
#         6    0.000    0.000    0.081    0.013 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:691(do_execute)
#         4    0.000    0.000    0.079    0.020 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1102(execute)
#     30603    0.030    0.000    0.063    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:412(result)
#         9    0.000    0.000    0.046    0.005 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:144(_do_get_result)
#         9    0.000    0.000    0.046    0.005 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:351(_get_result)
#         9    0.046    0.005    0.046    0.005 {method 'store_result' of '_mysql.connection' objects}
#         9    0.000    0.000    0.029    0.003 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:354(_post_get_result)
#         9    0.000    0.000    0.029    0.003 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:325(_fetch_row)
#         8    0.029    0.004    0.029    0.004 {method 'fetch_row' of '_mysql.result' objects}
#     30603    0.027    0.000    0.027    0.000 C:\Users\Computer\anaconda3\lib\threading.py:81(RLock)
#         3    0.000    0.000    0.023    0.008 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:133(_wrap_result)
#     61222    0.017    0.000    0.022    0.000 C:\Users\Computer\anaconda3\lib\threading.py:249(__exit__)
#         3    0.001    0.000    0.022    0.007 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:1724(from_records)
#     29834    0.021    0.000    0.021    0.000 {built-in method _thread.allocate_lock}
#        10    0.000    0.000    0.021    0.002 C:\Users\Computer\anaconda3\lib\threading.py:834(start)
#        10    0.000    0.000    0.020    0.002 C:\Users\Computer\anaconda3\lib\threading.py:540(wait)
#         3    0.000    0.000    0.017    0.006 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502(to_arrays)
#         4    0.000    0.000    0.017    0.004 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:62(arrays_to_mgr)
#        11    0.016    0.001    0.016    0.001 {pandas._libs.lib.maybe_convert_objects}
#     29821    0.011    0.000    0.015    0.000 C:\Users\Computer\anaconda3\lib\threading.py:258(_acquire_restore)
#        18    0.001    0.000    0.015    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:423(sanitize_array)
#         4    0.000    0.000    0.015    0.004 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:333(_homogenize)
#     29821    0.008    0.000    0.013    0.000 C:\Users\Computer\anaconda3\lib\threading.py:261(_is_owned)
#         2    0.000    0.000    0.012    0.006 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:109(maybe_convert_platform)
#         3    0.000    0.000    0.012    0.004 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:994(fetchall)
#         3    0.000    0.000    0.012    0.004 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:402(_allrows)
#     29821    0.008    0.000    0.011    0.000 C:\Users\Computer\anaconda3\lib\threading.py:255(_release_save)
#         3    0.010    0.003    0.010    0.003 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:410(<listcomp>)
#         3    0.000    0.000    0.008    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:555(_list_to_arrays)
#         3    0.008    0.003    0.008    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:551(<listcomp>)
#         9    0.000    0.000    0.006    0.001 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:250(query)
#         9    0.006    0.001    0.006    0.001 {function Connection.query at 0x000002ABB5CC5040}
#     30609    0.006    0.000    0.006    0.000 {method '__enter__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.006    0.002 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:713(_convert_object_array)
#         3    0.000    0.000    0.006    0.002 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:736(<listcomp>)
#         9    0.000    0.000    0.006    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:730(convert)
#     30603    0.006    0.000    0.006    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:386(__get_result)
# 61066/60951    0.005    0.000    0.005    0.000 {built-in method builtins.len}
#         2    0.005    0.002    0.005    0.002 {built-in method builtins.max}
#     59620    0.005    0.000    0.005    0.000 {built-in method time.monotonic}
#         5    0.000    0.000    0.004    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:314(__call__)
#         1    0.000    0.000    0.004    0.004 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1636(go)
#         1    0.000    0.000    0.004    0.004 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:663(first_connect)
#         1    0.000    0.000    0.004    0.004 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2875(initialize)
#     30604    0.003    0.000    0.003    0.000 {method 'put' of '_queue.SimpleQueue' objects}
#     30613    0.003    0.000    0.003    0.000 {method '__exit__' of '_thread.lock' objects}
#     29811    0.003    0.000    0.003    0.000 {method 'remove' of 'collections.deque' objects}
#     29832    0.003    0.000    0.003    0.000 {method 'release' of '_thread.lock' objects}
#     29838    0.003    0.000    0.003    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.003    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:2199(to_json)
#         1    0.000    0.000    0.003    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:48(to_json)
#     30604    0.003    0.000    0.003    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.003    0.003 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:213(__init__)
#         3    0.002    0.001    0.002    0.001 {pandas._libs.lib.to_object_array_tuples}
#     30609    0.002    0.000    0.002    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1522(exec_driver_sql)
#         4    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1690(create_block_manager_from_arrays)
#        12    0.002    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1617(construct_1d_object_array_from_listlike)
#     25/10    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:250(__new__)
#         1    0.000    0.000    0.002    0.002 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:3321(_detect_sql_mode)
#         6    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1861(_soft_close)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1773(_fetchall_impl)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:971(fetchall)
#         4    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1733(_form_blocks)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1039(close)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:1000(close)
#         4    0.000    0.000    0.002    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:641(do_rollback)
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:852(_checkin)
#         4    0.002    0.000    0.002    0.000 {method 'rollback' of '_mysql.connection' objects}
#         3    0.000    0.000    0.002    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:615(_finalize_fairy)
#         1    0.002    0.002    0.002    0.002 <ipython-input-38-29646a735120>:123(<listcomp>)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:882(__getitem__)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:867(_reset)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3601(select_dtypes)
# 3264/3255    0.001    0.000    0.001    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\ops\common.py:50(new_method)
#         2    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:27(__eq__)
#         2    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4969(_cmp_method)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:909(_getbool_axis)
#        24    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:238(__init__)
#         2    0.001    0.001    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\registry.py:53(_collection_gced)
#        24    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3783(_get_item_cache)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3591(_take_with_is_copy)
#        48    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5836(ensure_index)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:3278(_detect_casing)
#         2    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:1092(_getitem_axis)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3492(take)
#        25    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:367(initialize)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py:309(_execute_on_connection)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1341(_execute_clauseelement)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1454(take)
#         4    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:772(tolist)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:112(_parse_date_columns)
#        19    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:1013(items)
#         4    0.001    0.000    0.001    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:194(comparison_op)
#        16    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2721(make_block)
#        27    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2672(get_block_type)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2791(intersection)
#         5    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1844(_multi_blockify)
#       255    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:254(is_dtype)
#         1    0.000    0.000    0.001    0.001 <ipython-input-38-29646a735120>:43(clean_text_vi)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4499(replace)
#         6    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:376(apply)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:6489(replace)
#         2    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:118(_na_arithmetic_op)
#         2    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:218(evaluate)
#         2    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:98(_evaluate_numexpr)
#         3    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1260(reindex_indexer)
#        24    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1379(maybe_cast_to_datetime)
#        16    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:554(_try_cast)
#      1213    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\generic.py:30(_check)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3147(__setitem__)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4009(apply)
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3231(_set_item)
#         9    0.000    0.000    0.001    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:2987(__getitem__)
#        10    0.001    0.000    0.001    0.000 {built-in method _thread.start_new_thread}
#         1    0.000    0.000    0.001    0.001 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2843(_intersection)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1377(_setup_result_proxy)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:648(replace)
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\algorithms.py:1661(take_nd)
#        13    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:998(iget)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1441(_setup_dml_or_text_result)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3824(_set_item)
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1860(_stack_arrays)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1176(insert)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\numexpr\necompiler.py:767(evaluate)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1215(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:296(set_character_set)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2605(replace)
#        43    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:127(__init__)
#         1    0.000    0.000    0.000    0.000 {function Connection.set_character_set at 0x000002ABB5CC5310}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:759(replace)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2808(_get_default_schema_name)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:1448(_getitem_tuple)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1311(<listcomp>)
#       192    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1470(is_extension_array_dtype)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:1378(take_nd)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:2734(_construct_result)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1264(_init_metadata)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5680(dtypes)
#        17    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:157(blknos)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:157(__init__)
#        20    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1273(maybe_infer_to_datetimelike)
#        89    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:463(is_period_dtype)
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:232(_rebuild_blknos_and_blklocs)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\missing.py:26(mask_missing)
#         9    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:126(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:763(_getitem_tuple_same_dim)
#       207    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1610(_is_dtype_type)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2672(_get_server_version_info)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:1479(_getitem_axis)
#        13    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3306(_box_col_values)
#        59    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1577(from_array)
#        22    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:206(shape)
#        61    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:328(_name_get)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5544(insert)
#        62    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5467(__setattr__)
#        69    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:923(is_dtype)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\construction.py:364(extract_index)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:318(_verify_integrity)
#        12    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\ipykernel\iostream.py:386(write)
#        81    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:499(is_interval_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\connections.py:236(autocommit)
#      1799    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        91    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:537(is_categorical_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1829(_simple_blockify)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:434(get_default_isolation_level)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2635(get_isolation_level)
#        82    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:201(is_object_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\create.py:652(on_connect)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py:123(on_connect)
#         1    0.000    0.000    0.000    0.000 {function Connection.autocommit at 0x000002ABB5CC0EE0}
#        66    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:208(<genexpr>)
#       196    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\base.py:411(find)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:288(_merge_cursor_description)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:2715(execution_options)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3180(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_table_schema.py:192(build_table_schema)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:417(<listcomp>)
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\ipykernel\iostream.py:197(schedule)
#         9    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6023(_maybe_cast_data_without_dtype)
#        43    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:269(mgr_locs)
#        25    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:198(asarray_tuplesafe)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5947(default_index)
#        61    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\dtypes.py:1132(is_dtype)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\threading.py:761(__init__)
#        27    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5411(__finalize__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:1933(__array_ufunc__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:4603(isin)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:231(array_ufunc)
#        54    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:388(is_datetime64tz_dtype)
#     34/30    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        13    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numeric.py:289(full)
#        30    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1341(is_bool_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3142(get_indexer)
#        85    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:742(take)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3025(_convert_can_do_setop)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:659(pandasSQL_builder)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:85(__new__)
#        11    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:50(isna)
#        33    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:188(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5724(astype)
#        16    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:1257(maybe_castable)
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3036(get_loc)
#        11    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:133(_isna)
#        24    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:5889(copy)
#        27    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:288(make_block_same_class)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:542(maybe_promote)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_table_schema.py:104(convert_pandas_type_to_json_field)
#        34    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\construction.py:354(extract_array)
#        26    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:2238(check_bool_indexer)
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\zmq\sugar\socket.py:432(send)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4175(_coerce_scalar_to_index)
#        44    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5953(maybe_extract_name)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1327(_slice_take_blocks_ax0)
#        24    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_methods.py:54(_any)
#        69    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1769(pandas_dtype)
#        16    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1090(__get__)
#        35    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:538(name)
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\algorithms.py:1534(_get_take_nd_function)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\missing.py:202(_isna_ndarraylike)
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1335(get_result_processor)
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_asarray.py:22(require)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:796(copy)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:72(_can_use_numexpr)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:1157(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py:508(_compile_w_cache)
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5287(_maybe_cast_indexer)
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.arange}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:257(get_dtypes)
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1764(is_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:4817(reset_index)
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\type_api.py:574(_cached_result_processor)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:446(checkin)
#     88/83    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#       100    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\abc.py:96(__instancecheck__)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\deprecations.py:266(warned)
#        20    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:573(is_string_dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexers.py:363(check_array_indexer)
#        61    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_dtype.py:314(_name_includes_bit_suffix)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:752(copy)
#        57    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexers.py:225(maybe_convert_indices)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:628(astype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:310(reconstruct)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1059(_init_statement)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3695(<genexpr>)
#        28    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1551(_is_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\algorithms.py:415(isin)
#         3    0.000    0.000    0.000    0.000 <string>:1(__init__)
#       2/1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1654(infer_dtype_from_object)
#        27    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:231(is_sparse)
#       833    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        14    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1875(is_floating)
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2127(inferred_type)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:2694(update_execution_options)
#        48    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4070(_values)
#        13    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(copyto)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\base.py:303(_return_conn)
#        35    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1743(validate_all_hashable)
#         7    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:133(_simple_new)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1951(_fast_count_smallints)
#        55    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:429(is_timedelta64_dtype)
#        18    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:425(_simple_new)
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4393(equals)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1199(should_autocommit)
#        20    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:597(_merge_cols_by_none)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py:109(_do_return_conn)
#        57    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        56    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1575(get_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:152(_data)
#        24    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:4279(__getitem__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:1811(unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:1037(unique)
#       100    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        29    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:703(is_integer_dtype)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\_ufunc_config.py:32(seterr)
#        51    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:488(name)
#        40    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1017(_handle_fromlist)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\queue.py:91(put)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(prod)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:592(astype)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\threading.py:505(__init__)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_table_schema.py:34(as_json_table_type)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:840(infer_dtype_from_array)
#       215    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\algorithms.py:319(unique)
#         9    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:1312(_soft_close)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:602(condition)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:1071(is_numeric_v_string_like)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:145(write)
#        10    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5969(_maybe_cast_with_dtype)
#        18    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\MySQLdb\cursors.py:128(nextset)
#        30    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:473(dtype)
#        20    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:356(issubdtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\schema.py:4228(__init__)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:620(array)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\log.py:181(instance_logger)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\common.py:605(is_excluded_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2970(prod)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\lib\index_tricks.py:322(__getitem__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3833(_sanitize_column)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1300(create_cursor)
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.json.dumps}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:597(find_common_type)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\common.py:75(is_bool_indexer)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:558(_only_one_row)
# ...
#        14    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         8    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:623(dtype)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:313(dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3284(_ensure_valid_index)
#         9    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:422(_constructor)
#         1    0.000    0.000    0.000    0.000 <string>:1(_generated_cache_key_traversal)
#         8    0.000    0.000    0.000    0.000 {method 'field_flags' of '_mysql.result' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:70(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\log.py:218(__get__)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\result.py:123(<listcomp>)
#        13    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         3    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:359(__exit__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:304(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:353(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\dtypes\inference.py:360(is_sequence)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:64(__iter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:1281(_get_names)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py:917(get)
#         1    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:649(<listcomp>)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:756(_maybe_disallow_fill)
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:482(_constructor)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1622(external_values)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py:149(_inc_overflow)
#         1    0.000    0.000    0.000    0.000 <string>:1(__new__)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arrays\numpy_.py:202(__array__)
#         3    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         6    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\compat\numpy\function.py:45(__call__)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:405(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         3    0.000    0.000    0.000    0.000 {method 'intersection' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:434(connection)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:326(_supports_statement_cache)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1332(post_exec)
#         2    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:69(_convert_params)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\sql.py:80(_process_parse_dates_argument)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:930(soft_close)
#         5    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:182(<genexpr>)
#         9    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:581(<lambda>)
#         3    0.000    0.000    0.000    0.000 {method 'union' of 'sqlalchemy.cimmutabledict.immutabledict' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:882(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:272(<listcomp>)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:261(fill_value)
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexing.py:759(_validate_key_length)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py:4859(__new__)
#         6    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1324(pre_exec)
#         2    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         5    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:3160(_ndim_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:183(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:606(__array__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2722(_set_mariadb)
#         6    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#         5    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         8    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\inspect.py:72(isclass)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\util.py:134(_distill_params_20)
#         1    0.000    0.000    0.000    0.000 <ipython-input-38-29646a735120>:21(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {built-in method sys._getframe}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:628(axes)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3863(_check_setitem_copy)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:933(hard_close)
#        10    0.000    0.000    0.000    0.000 {method 'locked' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:3207(_get_pool)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:207(start)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:227(is_single_block)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\managers.py:1634(is_consolidated)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\_collections.py:913(_inc_counter)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\event\attr.py:328(__bool__)
#         2    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\traversals.py:954(__init__)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\arraylike.py:271(<genexpr>)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:2602(_can_hold_element)
#         3    0.000    0.000    0.000    0.000 {method 'character_set_name' of '_mysql.connection' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\missing.py:64(clean_fill_method)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3304(_get_partial_string_timestamp_match_key)
#         3    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\type_api.py:291(result_processor)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\process.py:478(_chain_from_iterable_of_lists)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2932(_is_mysql)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:613(min_scalar_type)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:148(concatenate)
#         4    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\base.py:397(ndim)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:230(stop)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:253(step)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\series.py:781(axes)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\cursor.py:201(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\concurrent\futures\_base.py:632(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:884(<genexpr>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:498(can_cast)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:2965(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\io\json\_json.py:285(obj_to_write)
#         1    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'difference' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get_autocommit' of '_mysql.connection' objects}
#         1    0.000    0.000    0.000    0.000 {method 'get_server_info' of '_mysql.connection' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\contextlib.py:356(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py:1298(<genexpr>)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\fromnumeric.py:1751(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\lib\function_base.py:5333(_append_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\_config\config.py:816(is_nonnegative_int)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\base.py:2636(_validate_sort_keyword)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\internals\blocks.py:222(external_values)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\dialects\mysql\base.py:2903(_warn_for_known_db_issues)
#         1    0.000    0.000    0.000    0.000 {built-in method time.perf_counter}
#         1    0.000    0.000    0.000    0.000 {method 'isdigit' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:715(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\sql\compiler.py:718(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'isdisjoint' of 'frozenset' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\typing.py:1149(cast)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\multiarray.py:883(bincount)
#         2    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\numerictypes.py:650(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\indexes\range.py:317(is_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\frame.py:3696(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\pandas\core\generic.py:3978(_check_inplace_and_allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:422(_check_max_identifier_length)
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:1025(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\Computer\AppData\Roaming\Python\Python38\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)

# %%
import multiprocessing as mp
print("Number of processors: ", mp.cpu_count())
# Out:
# Number of processors:  6

# %%
import cProfile
import pandas as pd
#import sys
from sqlalchemy import create_engine
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
import spacy
from sklearn.feature_extraction.text import CountVectorizer
import string
import concurrent.futures
import time
import optparse


## Implement the string data

def remove_punctuations(txt, punct = string.punctuation):
    '''
    This function will remove punctuations from the input text
    '''
    return ''.join([c for c in txt if c not in punct])

def remove_stopwords(txt, sw = list(stopwords.words('english'))):
    '''
    This function will remove the stopwords from the input txt
    '''
    return ' '.join([w for w in txt.split() if w.lower() not in sw])


en_nlp = spacy.load('en_core_web_sm')

def clean_text(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)
    txt = remove_stopwords(txt)
    return txt.lower()

def clean_text_vi(txt):
    '''
    This function will clean the text being passed by removing specific line feed characters
    like '\n', '\r', and '\'
    '''

    txt = txt.replace('\n', ' ').replace('\r', ' ').replace('\'', '')
    txt = remove_punctuations(txt)

    return txt.lower()
def lemma_text(text_line):
    #test_file_clean = []
    doc_spacy = en_nlp(text_line)
    line = [ a.lemma_ for a in doc_spacy]
    #sentence = " ".join(line)
    #test_file_clean.append(sentence)
    return " ".join(line)



vectorizer1 = CountVectorizer(ngram_range=(2,4),stop_words="english")
vectorizer2 = CountVectorizer(ngram_range=(2,4),stop_words="english",min_df=0.55)

class Checker():
    ## Connect to the MySQL server
    engine = create_engine('mysql://root:kakalot123@localhost:3306/db')
    # book_id =177
    # language = 'en'
    def __init__(self,version,score,test_id):
        self.version = version
        self.score = score
        self.test_id = test_id
        if(self.version =='esv'):
            self.book_id =177
            self.language ='en'
        elif(self.version =='vie2010'):
            self.book_id =397
            self.language ='vi'
        self.train_query = """select verses.id,verses.text from verses  inner join books on verses.book_id = books.id where verses.book_id!={} and books.language='{}' and books.version='{}'""".format(self.book_id,self.language,self.version)
        self.train_model = pd.read_sql_query(self.train_query, self.engine)
        # print(self.test_id)
        # print(self.version)
        # print(self.book_id)
        # print(self.language)
        self.test_query = """select verses.id,verses.text from verses  inner join books on verses.book_id = books.id where verses.book_id={} and books.language='{}' and verses.id ={} and books.version='{}'""".format(self.book_id,self.language,self.test_id,self.version)
        self.test_model = pd.read_sql_query(self.test_query,self.engine)
        self.text = self.train_model['text'].tolist()
        self.verses_id = self.train_model['id'].tolist()
        self.s_vector = list(zip(self.verses_id,self.text))
        self.test_file = self.test_model['text'].apply(str)

    def check_plagiarism(self,train_file,test_file,vectorizer):
        documents = [train_file,test_file]
        sparse_matrix = vectorizer.fit_transform(documents)
        score = cosine_similarity(sparse_matrix)[0][1]
        return score
    def show_result(self,train_file,test_file):

        score = self.check_plagiarism(train_file,test_file,vectorizer1)
        if score >float(self.score):
            score = self.check_plagiarism(train_file,test_file,vectorizer2)
        return score



    #def check_plagiarism_soft(self,test_file,s_vector):
    def check_plagiarism_soft(self):
#         self.test_file = test_file
#         self.text = text
#         self.verses_id = verses_id
#         self.s_vector = s_vector
        result = {"id":[],"score":[]}

        if(self.version=='esv'):
            self.text = [clean_text(txt) for txt in self.text]
            self.text = [lemma_text(txt) for txt in self.text ]
            self.test_file = clean_text(self.test_file)
            self.test_file = lemma_text(self.test_file)
        elif(self.version =='vie2010'):
            self.test_file = clean_text_vi(self.test_file)
        test_file_list =[self.test_file for i in range(len(self.text))]
#         for i in range(len(self.text)):
#             test_file_list.append()
        result['id'] = self.verses_id
        #score = []
#         with concurrent.futures.ThreadPoolExecutor() as executor:
#             score= executor.map(self.show_result,self.text,test_file_list)
        score = pool.starmap(self.show_result, zip(self.text,test_file_list))
        pool.close()  
        result['score'] = score

#         for a,v_vector in self.s_vector:
#             test_file = clean_text(self.test_file)

#             if(self.version=='esv'):
#                 v_vector = clean_text(v_vector)
#                 test_file = lemma_text(test_file)
#                 v_vector = lemma_text(v_vector)
#             elif(self.version =='vie2010'):
#                 v_vector = clean_text_vi(v_vector)
#             score = self.show_result(v_vector,test_file)
#             result['id'].append(a)
#                 #score.append(executor.submit(self.show_result, train_file=v_vector,test_file=test_file))
#             result['score'].append(score)

        #     result['score'] = score
        dt = pd.DataFrame(result)
        result_file =[dt.loc[dt['score']==max(dt['score'])]['id'].tolist()[0],dt.loc[dt['score']==max(dt['score'])]['score'].tolist()[0]]
        return result_file


    def show_final_result(self):
        #result = self.check_plagiarism_soft(self.test_file,self.s_vector)
        result = self.check_plagiarism_soft()
        result_model = pd.read_sql_query(f"select verses.id,verses.book_id,verses.chapter,verses.number,verses.text from verses where verses.id={result[0]}", self.engine)
        result_model['score'] = result[1]
        df = result_model.to_json(orient='table',index=False)
        return df

def main():
    start = time.time()
    #parser = optparse.OptionParser()

    # add options
#     parser.add_option('-v','--version', dest = 'version',
#                       type = 'string',
#                       help = 'choose english or vietnamese version')
#     parser.add_option('-t','--testid', dest = 'testid',
#                       type = 'string',
#                       help = 'please enter the test id')
#     parser.add_option('-s','--score', dest = 'score',
#                       type = 'string',
#                       help = 'please enter the algorithm score')


#     (options, args) = parser.parse_args()
#     if (options.version == None):
#             print ("Version is not null")
#             exit(0)
#     else:
#             version = options.version

#     if (options.testid == None):
#             print ("Test id is not null")
#             exit(0)
#     else:
#             testid = options.testid

#     if (options.score == None):
#             print ("The score is not null")
#             exit(0)
#     else:
#             score = options.score
    my_checker = Checker('vie2010','0.3','199107')
    print(my_checker.version)
    print(my_checker.score)
    print(my_checker.test_id)
    print(my_checker.show_final_result())

    end = time.time()
    print("It takes: ",end -start)


if __name__ == "__main__":
    import cProfile, pstats
    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()
    stats = pstats.Stats(profiler).sort_stats('cumtime')
    stats.print_stats()
# Out:
# vie2010
# 0.3
# 199107

# %%
import multiprocessing as mp
pool = mp.Pool(mp.cpu_count())
print(mp.cpu_count())
# Out:
# 6
